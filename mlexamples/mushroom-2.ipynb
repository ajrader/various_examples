# %% [markdown]
# # Looking at Mushroom dataset from UCI repository : http://archive.ics.uci.edu/ml/datasets/Mushroom

# %% [markdown]
# ## Simple way to load the categorical data using Pandas

# %%
import os
os.chdir('../../../data/miscDataSets/mushroom/')
infile = 'agaricus-lepiota.data'

# %%
#column names are in .names file
colNames = ['tgtclass', 'cap-shape','cap-surface','cap-color','bruises','odor',\
'gill-attachment','gill-spacing','gill-size','gill-color','stalk-shape','stalk-root',\
'stalk-surface-above-ring','stalk-surface-below-ring','stalk-color-above-ring',\
'stalk-color-below-ring','veil-type','veil-color','ring-number','ring-type','spore-print-color',\
'population','habitat']
len(colNames) #this is the number of attributes + 1 (corresponding to the tgtclass --> first column)
# 1st column has edible=e; poisonous=p
# Out:
# 23

# %%
import pandas as pd
mraw = pd.read_csv(infile,header=None,names=colNames,na_values='?')
shape(mraw)
# Out:
# (8124, 23)

# %% [markdown]
# ##### Replace the '-' in column names with underscore '_'

# %%
mraw.columns = map(lambda x: x.lower().replace('-','_'), mraw.columns)

# %%
mraw
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8124 entries, 0 to 8123
# Data columns (total 23 columns):
# tgtclass                    8124  non-null values
# cap_shape                   8124  non-null values
# cap_surface                 8124  non-null values
# cap_color                   8124  non-null values
# bruises                     8124  non-null values
# odor                        8124  non-null values
# gill_attachment             8124  non-null values
# gill_spacing                8124  non-null values
# gill_size                   8124  non-null values
# gill_color                  8124  non-null values
# stalk_shape                 8124  non-null values
# stalk_root                  5644  non-null values
# stalk_surface_above_ring    8124  non-null values
# stalk_surface_below_ring    8124  non-null values
# stalk_color_above_ring      8124  non-null values
# stalk_color_below_ring      8124  non-null values
# veil_type                   8124  non-null values
# veil_color                  8124  non-null values
# ring_number                 8124  non-null values
# ring_type                   8124  non-null values
# spore_print_color           8124  non-null values
# population                  8124  non-null values
# habitat                     8124  non-null values
# dtypes: object(23)

# %% [markdown]
# ### Cope with missing data. In this example only the 11th attribute 'stalk_root' has missing values, denoted by '?'; mapped to NaN

# %%
pd.isnull(mraw).any()
# Out:
# tgtclass                    False
# cap_shape                   False
# cap_surface                 False
# cap_color                   False
# bruises                     False
# odor                        False
# gill_attachment             False
# gill_spacing                False
# gill_size                   False
# gill_color                  False
# stalk_shape                 False
# stalk_root                   True
# stalk_surface_above_ring    False
# stalk_surface_below_ring    False
# stalk_color_above_ring      False
# stalk_color_below_ring      False
# veil_type                   False
# veil_color                  False
# ring_number                 False
# ring_type                   False
# spore_print_color           False
# population                  False
# habitat                     False
# dtype: bool

# %%
# how many are missing?
print mraw['stalk_root'].value_counts()

nmissing = sum(pd.isnull(mraw['stalk_root']))
ntotal = len(mraw)
print "\n\n%f percent missing for this attribute" % (nmissing/float(ntotal) * 100)
# Out:
# b    3776
# e    1120
# c     556
# r     192
# dtype: int64
#
#
# 30.526834 percent missing for this attribute

# %%
mraw.tgtclass.value_counts()
# Out:
# e    4208
# p    3916
# dtype: int64

# %% [markdown]
# <h1> I want to convert from characters to integers for use with Marketbasket analysis.</h1>
# <p> The plan is to loop through each column, map letters to integers and add 10*column number to the value.</p>

# %%
colCount = 0
cdValues =[]
for col in mraw.columns:
    print len(mraw[col].unique()), colCount*10
    cdValues.append(mraw[col].unique())
    colCount+=1
# Out:
# 2 0
# 6 10
# 4 20
# 10 30
# 2 40
# 9 50
# 2 60
# 2 70
# 2 80
# 12 90
# 2 100
# 5 110
# 4 120
# 4 130
# 9 140
# 9 150
# 1 160
# 4 170
# 3 180
# 5 190
# 9 200
# 6 210
# 7 220

# %%
cdValues
# Out:
# [array(['p', 'e'], dtype=object),
#  array(['x', 'b', 's', 'f', 'k', 'c'], dtype=object),
#  array(['s', 'y', 'f', 'g'], dtype=object),
#  array(['n', 'y', 'w', 'g', 'e', 'p', 'b', 'u', 'c', 'r'], dtype=object),
#  array(['t', 'f'], dtype=object),
#  array(['p', 'a', 'l', 'n', 'f', 'c', 'y', 's', 'm'], dtype=object),
#  array(['f', 'a'], dtype=object),
#  array(['c', 'w'], dtype=object),
#  array(['n', 'b'], dtype=object),
#  array(['k', 'n', 'g', 'p', 'w', 'h', 'u', 'e', 'b', 'r', 'y', 'o'], dtype=object),
#  array(['e', 't'], dtype=object),
#  array(['e', 'c', 'b', 'r', nan], dtype=object),
#  array(['s', 'f', 'k', 'y'], dtype=object),
#  array(['s', 'f', 'y', 'k'], dtype=object),
#  array(['w', 'g', 'p', 'n', 'b', 'e', 'o', 'c', 'y'], dtype=object),
#  array(['w', 'p', 'g', 'b', 'n', 'e', 'y', 'o', 'c'], dtype=object),
#  array(['p'], dtype=object),
#  array(['w', 'n', 'o', 'y'], dtype=object),
#  array(['o', 't', 'n'], dtype=object),
#  array(['p', 'e', 'l', 'f', 'n'], dtype=object),
#  array(['k', 'n', 'u', 'h', 'w', 'r', 'o', 'y', 'b'], dtype=object),
#  array(['s', 'n', 'a', 'v', 'y', 'c'], dtype=object),
#  array(['u', 'g', 'm', 'd', 'p', 'w', 'l'], dtype=object)]

# %% [markdown]
# ### since this is approx 30% of the examples; probably best to omit this column for now.

# %%
#Explore a couple of attributes
print colNames[5]
print mraw['odor'].value_counts()
print "--------------------------"
print colNames[22]
print mraw['habitat'].value_counts()
# note that they are already coded by 1 letter abbreviations
# Out:
# odor
# n    3528
# f    2160
# y     576
# s     576
# l     400
# a     400
# p     256
# c     192
# m      36
# dtype: int64
# --------------------------
# habitat
# d    3148
# g    2148
# p    1144
# l     832
# u     368
# m     292
# w     192
# dtype: int64

# %%
#make a little bar plot example
fig, axes = plt.subplots(2,1)

mraw['odor'].value_counts().plot(kind='bar',color='c',ax=axes[0])

mraw['habitat'].value_counts().plot(kind='bar',color='m',ax=axes[1])

# %%
# nifty tool to see cross-tabulation of features
pd.crosstab(mraw['habitat'],mraw['odor'])
# Out:
# odor       a    c    f    l   m     n    p    s    y
# habitat
# d         48  192  624   48  36  1816    0  192  192
# g        176    0  576  176   0  1092  128    0    0
# l          0    0  192    0   0   256    0  192  192
# m        128    0    0  128   0    36    0    0    0
# p         48    0  624   48   0    40    0  192  192
# u          0    0  144    0   0    96  128    0    0
# w          0    0    0    0   0   192    0    0    0

# %% [markdown]
# ### DROP stalk-root column

# %%
mm = mraw.dropna(axis=1)
cnames = mm.columns
shape(mm)
# Out:
# (8124, 22)

# %% [markdown]
# ### Explicitly pull out target class and map to a binary class

# %%
mmY = mm['tgtclass'].values
mushY = map(lambda x: 0 if x=='e' else 1, mmY)
# map edible=e to '0', poisonous=p to 1 (only 2 classes here)

# %%
print "%g are 1 (poisonous) and %g are 0 (edible) \n" % (len(filter(lambda x: x == 1, mushY)), len(filter(lambda x: x==0,mushY)))
# Out:
# 3916 are 1 (poisonous) and 4208 are 0 (edible)

# %% [markdown]
# ### Find out how many values are present for each attribute in this dataset

# %%
attributeCounts = []
for i in xrange(1,len(mm.columns)):
    colname = str(cnames[i])
    print i, colname
    #le.fit(mraw[colname])
    #b = le.transform(mraw[colname])
    aa = mm[colname].value_counts()
    print aa
    print "------------------------------------"
    attributeCounts.append([colname, len(aa), aa.keys(), aa.values])
# Out:
# 1 cap_shape
# x    3656
# f    3152
# k     828
# b     452
# s      32
# c       4
# dtype: int64
# ------------------------------------
# 2 cap_surface
# y    3244
# s    2556
# f    2320
# g       4
# dtype: int64
# ------------------------------------
# 3 cap_color
# n    2284
# g    1840
# e    1500
# y    1072
# w    1040
# b     168
# p     144
# c      44
# u      16
# r      16
# dtype: int64
# ------------------------------------
# 4 bruises
# f    4748
# t    3376
# dtype: int64
# ------------------------------------
# 5 odor
# n    3528
# f    2160
# y     576
# s     576
# l     400
# a     400
# p     256
# c     192
# m      36
# dtype: int64
# ------------------------------------
# 6 gill_attachment
# f    7914
# a     210
# dtype: int64
# ------------------------------------
# 7 gill_spacing
# c    6812
# w    1312
# dtype: int64
# ------------------------------------
# 8 gill_size
# b    5612
# n    2512
# dtype: int64
# ------------------------------------
# 9 gill_color
# b    1728
# p    1492
# w    1202
# n    1048
# g     752
# h     732
# u     492
# k     408
# e      96
# y      86
# o      64
# r      24
# dtype: int64
# ------------------------------------
# 10 stalk_shape
# t    4608
# e    3516
# dtype: int64
# ------------------------------------
# 11 stalk_surface_above_ring
# s    5176
# k    2372
# f     552
# y      24
# dtype: int64
# ------------------------------------
# 12 stalk_surface_below_ring
# s    4936
# k    2304
# f     600
# y     284
# dtype: int64
# ------------------------------------
# 13 stalk_color_above_ring
# w    4464
# p    1872
# g     576
# n     448
# b     432
# o     192
# e      96
# c      36
# y       8
# dtype: int64
# ------------------------------------
# 14 stalk_color_below_ring
# w    4384
# p    1872
# g     576
# n     512
# b     432
# o     192
# e      96
# c      36
# y      24
# dtype: int64
# ------------------------------------
# 15 veil_type
# p    8124
# dtype: int64
# ------------------------------------
# 16 veil_color
# w    7924
# o      96
# n      96
# y       8
# dtype: int64
# ------------------------------------
# 17 ring_number
# o    7488
# t     600
# n      36
# dtype: int64
# ------------------------------------
# 18 ring_type
# p    3968
# e    2776
# l    1296
# f      48
# n      36
# dtype: int64
# ------------------------------------
# 19 spore_print_color
# w    2388
# n    1968
# k    1872
# h    1632
# r      72
# u      48
# b      48
# o      48
# y      48
# dtype: int64
# ------------------------------------
# 20 population
# v    4040
# y    1712
# s    1248
# n     400
# a     384
# c     340
# dtype: int64
# ------------------------------------
# 21 habitat
# d    3148
# g    2148
# p    1144
# l     832
# u     368
# m     292
# w     192
# dtype: int64
# ------------------------------------

# %%
len(attributeCounts)
# Out:
# 21

# %%
total_attribute_space = 0 # find out how large of an array is required if a one-hot encoder is used; more on this later
for i in xrange(0,len(attributeCounts)):
    print i, attributeCounts[i][0],attributeCounts[i][1]
    total_attribute_space +=attributeCounts[i][1]
        
print "---------------------------------------------"
print "\n this corresponds to an expanded set of %g features from %g initial features" % (total_attribute_space,len(attributeCounts))
# Out:
# 0 cap_shape 6
# 1 cap_surface 4
# 2 cap_color 10
# 3 bruises 2
# 4 odor 9
# 5 gill_attachment 2
# 6 gill_spacing 2
# 7 gill_size 2
# 8 gill_color 12
# 9 stalk_shape 2
# 10 stalk_surface_above_ring 4
# 11 stalk_surface_below_ring 4
# 12 stalk_color_above_ring 9
# 13 stalk_color_below_ring 9
# 14 veil_type 1
# 15 veil_color 4
# 16 ring_number 3
# 17 ring_type 5
# 18 spore_print_color 9
# 19 population 6
# 20 habitat 7
# ---------------------------------------------
#
#  this corresponds to an expanded set of 112 features from 21 initial features

# %% [markdown]
# ### This would be tedious to encode manually for each value of each attribute

# %% [markdown]
# #### I need to create a dictionary for each column  import the dictionary that is located in the .names file

# %%
from sklearn import preprocessing
le = preprocessing.LabelEncoder()

# %%
Ncol = len(mm.columns)
cnames = mm.columns

# %%
mshape = shape(mm)
Nobserv = len(mm)

mnew = pd.DataFrame(np.arange(mshape[0]*Ncol).reshape(mshape[0],mshape[1]),index=arange(mshape[0]),columns=mm.columns)
# create a new data frame with empty values
shape(mnew)
# Out:
# (8124, 22)

# %%
# transform each column into categorical labels
for i in xrange(0,len(mm.columns)):
    colname = str(cnames[i])
    #print i, colname,mm[colname].ix[0]
    le.fit(mm[colname])
    b = le.transform(mm[colname])
    mnew[colname] = b

# %%
# Nifty tool to explore relationships between the elements
from pandas.tools.plotting import scatter_matrix

scatter_matrix(mnew[['odor','spore_print_color','habitat','cap_color']], figsize=(12, 12), marker='o',alpha=0.3);

# %% [markdown]
# # Convert to arrays for analysis using a Decision Tree

# %%
#mushY already created above
mushX = mnew.drop(['tgtclass'],axis=1).values

# %%
from sklearn import tree
clf = tree.DecisionTreeClassifier()

# %%
#little script for visualizing/saving Decision Tree
from StringIO import StringIO
from IPython.core.display import HTML
dot_data = StringIO()

fullDT_clf = clf.fit(mushX,mushY)
dot_data = tree.export_graphviz(fullDT_clf,out_file=dot_data)
#print dot_data.getvalue()

import pydot
graph = pydot.graph_from_dot_data(dot_data.getvalue())
graph.write_png('full_tree.png')
HTML('<img src="full_tree.png">')
# Out:
# <img src="full_tree.png">

# %%
predY = fullDT_clf.predict(mushX)

# %%
from sklearn import metrics 
print metrics.confusion_matrix(mushY,predY)
print metrics.accuracy_score(mushY,predY)
# Out:
# [[4208    0]
#  [   0 3916]]
# 1.0

# %% [markdown]
# ### now assess the predictive power using a training set

# %%
#simple cross_validation
from sklearn import cross_validation
# withhold 30% for testing; setting seed to a value so this set is reproducible
X_train, X_test, y_train,y_test = cross_validation.train_test_split(mushX,mushY,test_size=0.3,random_state=42)
print X_train.shape,y_train.shape
print X_test.shape, y_test.shape

dt_clf = tree.DecisionTreeClassifier().fit(X_train,y_train)
dot_data = StringIO()
dot_data = tree.export_graphviz(dt_clf,out_file=dot_data)
graph = pydot.graph_from_dot_data(dot_data.getvalue())
graph.write_png('dt_test30pct.png')

# %%
from sklearn import metrics
predY = dt_clf.predict(X_test)
score = dt_clf.score(X_test, y_test)
print score
print metrics.precision_score(y_test,predY)

# %%
metrics.confusion_matrix(y_test,predY)

# %%
len(y_train[y_train == 1])

# %% [markdown]
# ## Explore the key Features

# %% [markdown]
# ### features used in the splits: X[8], X[18], X[19], X[20], X[7], X[4], X[12], X[16], X[9], X[11], X[1], X[3], X[2]

# %%
mnew[str(cnames[9])].value_counts()
# Out:
# 0     1728
# 7     1492
# 10    1202
# 5     1048
# 2      752
# 3      732
# 9      492
# 4      408
# 1       96
# 11      86
# 6       64
# 8       24
# dtype: int64

# %%
mnew.groupby('tgtclass')[str(cnames[19])].value_counts()
# Out:
# tgtclass
# 0         3    1744
#           2    1648
#           7     576
#           6      48
#           1      48
#           8      48
#           4      48
#           0      48
# 1         7    1812
#           1    1584
#           3     224
#           2     224
#           5      72
# dtype: int64

# %%
gg = mnew[mnew[str(cnames[9])] <= 3.5].groupby('tgtclass')
gg.gill_color.count()
# Out:
# tgtclass
# 0            548
# 1           2760
# dtype: int64

# %%
mushX[:10,8]
# Out:
# array([4, 4, 5, 5, 4, 5, 2, 5, 7, 2])

# %%
mnew[str(cnames[9])].head(10)
# Out:
# 0    4
# 1    4
# 2    5
# 3    5
# 4    4
# 5    5
# 6    2
# 7    5
# 8    7
# 9    2
# Name: gill_color, dtype: int32

# %%
print cnames[18], cnames[19],cnames[7],cnames[20]
# Out:
# ring_type spore_print_color gill_spacing population

# %%
X[:10,6]

# %%
len((y[X[:,6] <= 0.5] == 1).nonzero()[0])

# %%
len((mushX[:,8] <= 3.5).nonzero()[0])

# %%
len((mushY[mushX[:,8] >3.5] == 1).nonzero()[0])

# %%
mm.gill_color.unique()

# %%
print mm.gill_color.head(13), mushX[:13,8]

# %%
mushX[:13,8]

# %%
aindx = (mm.gill_color == 'h').nonzero()[0][0]
print aindx
print mushX[aindx,8]

# %%
aindx = (mm.gill_color == 'o').nonzero()[0][0]
print aindx
print mushX[aindx,8]

# %%
# list the left hand side split values in decision tree
mnew[mnew['gill_color'] <= 3.5].groupby('tgtclass')['tgtclass'].value_counts()
# Out:
# tgtclass
# 0         0     548
# 1         1    2760
# dtype: int64

# %%
mnew['gill_color'].value_counts()
# Out:
# 0     1728
# 7     1492
# 10    1202
# 5     1048
# 2      752
# 3      732
# 9      492
# 4      408
# 1       96
# 11      86
# 6       64
# 8       24
# dtype: int64

# %% [markdown]
# ### Documentation in .names file suggests logical rules including p1 odor=Not(almond.OR.anis.OR.none) captures 98.5 % accuracy

# %% [markdown]
# #### Why did DT miss this?

# %% [markdown]
# #### odor corresponds to X[4]

# %%
print cnames[5]
print mm[str(cnames[5])].value_counts()
print unique(mushX[4])
# Out:
# odor
# n    3528
# f    2160
# y     576
# s     576
# l     400
# a     400
# p     256
# c     192
# m      36
# dtype: int64
# [0 1 2 3 4 5 7]

# %% [markdown]
# #### almond = a = 0; anise = l = 3; none = n = 5 from the LabelEncoder used

# %%
# used to dermine above results; change name to desired key
search_char = 'n'
aindx = (mm.odor == search_char).nonzero()[0][0]
#print aindx
print search_char, mushX[aindx,4]
# Out:
# n 5

# %% [markdown]
# ### So we missed this with our DT because the keys for splitting on odor are not continous (just assigned as encountered by the LabelEncoder

# %%
#define groups using this rule
p1odor = mm[(mm.odor == 'n') | (mm.odor == 'l') | (mm.odor == 'a')]
notp1odor = mm[(mm.odor != 'n') & (mm.odor != 'l') & (mm.odor != 'a')]

# %%
print p1odor.groupby('tgtclass')['tgtclass'].count()
print "_______________________________"
notp1odor.groupby('tgtclass')['tgtclass'].count()
# Out:
# tgtclass
# e           4208
# p            120
# dtype: int64
# _______________________________
# tgtclass
# p           3796
# dtype: int64

# %% [markdown]
# ### Indeed this only misses 120 out of 8124 observations (i.e. fp = 120) so accuracy is 98.52%

# %% [markdown]
# # If we use an expanded attribute set such as one-hot (i.e. map each value a given attribute can take to a new dimension) can we identify this type of rule?

# %%
from sklearn.preprocessing import OneHotEncoder
enc = OneHotEncoder()
enc.fit(mushX)
mushX2 = enc.transform(mushX).toarray()
#mushX2 is the extended attribute space now
shape(mushX2)
# Out:
# (8124, 112)

# %% [markdown]
# ## Repeat DT on these 112 attributes

# %%
#little script for visualizing/saving Decision Tree
fullDT_X_clf = clf.fit(mushX2,mushY)
dot_data = StringIO()
dot_data = tree.export_graphviz(fullDT_X_clf,out_file=dot_data)

graph = pydot.graph_from_dot_data(dot_data.getvalue())
graph.write_png('full_X_tree.png')
#HTML('<img src="full_X_tree.png">')
# Out:
# True

# %% [markdown]
# ### Now the split involves 9 attributes: 27, 20, 95, 24, 58, 28, 1, 35, 7

# %%
splitAttrib = [27,20,95,24,58,28,1,35,7]

# %%
print len(enc.feature_indices_)
enc.feature_indices_
# Out:
# 22
# array([  0,   6,  10,  20,  22,  31,  33,  35,  37,  49,  51,  55,  59,
#         68,  77,  78,  82,  85,  90,  99, 105, 112])

# %%
enc.n_values_
# Out:
# array([ 6,  4, 10,  2,  9,  2,  2,  2, 12,  2,  4,  4,  9,  9,  1,  4,  3,
#         5,  9,  6,  7])

# %%
splitAttribOrigIND = [4,3, 18,4,11,4,0,7,1]
# Out:
#   File "<ipython-input-129-2471af6d45f0>", line 2
#     map(cnames[x+1],x : splitAttribOrigIND)
#                       ^
# SyntaxError: invalid syntax

# %%
[cnames[x+1] for x in splitAttribOrigIND]
# Out:
# ['odor',
#  'bruises',
#  'spore_print_color',
#  'odor',
#  'stalk_surface_below_ring',
#  'odor',
#  'cap_shape',
#  'gill_size',
#  'cap_surface']

# %%
# Breakdown of rhs of first split in full_DT_X
print mnew[mnew.odor == 5].groupby('tgtclass')['tgtclass'].count()
print "________________________"
# Breakdown of lhs of first split in full_DT_X
print mnew[mnew.odor != 5].groupby('tgtclass')['tgtclass'].count()
# Out:
# tgtclass
# 0           3408
# 1            120
# dtype: int64
# ________________________
# tgtclass
# 0            800
# 1           3796
# dtype: int64

# %%
# used to dermine above results; change name to desired key
search_char = 'p'
aindx = (mm.odor == search_char).nonzero()[0][0]
#print aindx
print search_char, mushX[aindx,4]
# Out:
# p 6

# %% [markdown]
# ## Look at the accuracy as it depends upon the depth (i.e. complexity of the Decision Tree)

# %%
dmax=3
three_clf = tree.DecisionTreeClassifier(max_depth=dmax)
fullDT_three= three_clf.fit(mushX2,mushY)
dot_data = StringIO()
dot_data = tree.export_graphviz(fullDT_three,out_file=dot_data)

graph = pydot.graph_from_dot_data(dot_data.getvalue())
graph.write_png('full_three_tree.png')
# Out:
# True

# %%
#check the accuracy and precision 
predY = fullDT_three.predict(mushX2)
score = fullDT_three.score(mushX2,mushY)
print score
#print metrics.precision_score(mushY,predY) gives same result as 'score' for categorical assignment
print metrics.precision_score(mushY,predY)
# Out:
# 0.965534219596
# 0.995637949836

# %% [markdown]
# #### Note that if we do the same level of complexity using the original 21 attributes we get the follwoing

# %%
fullDT_three_oa= three_clf.fit(mushX,mushY)
dot_data = StringIO()
dot_data = tree.export_graphviz(fullDT_three_oa,out_file=dot_data)

graph = pydot.graph_from_dot_data(dot_data.getvalue())
graph.write_png('full_three_OrigAttributes_tree.png')
#check the accuracy and precision 
predYoa = fullDT_three_oa.predict(mushX)
score = fullDT_three_oa.score(mushX,mushY)
print score
#print metrics.precision_score(mushY,predY) gives same result as 'score' for categorical assignment
print metrics.precision_score(mushY,predYoa)
# Out:
# 0.955686853767
# 0.943170488534

# %% [markdown]
# #### Consider a max_depth of 3: dmax = 3 and a training sample that is 70% of the data

# %%
#simple cross_validation
from sklearn import cross_validation
# withhold 30% for testing; setting seed to a value so this set is reproducible
X2_train, X2_test, y2_train,y2_test = cross_validation.train_test_split(mushX2,mushY,test_size=0.3,random_state=42)
X_train, X_test, y_train,y_test = cross_validation.train_test_split(mushX,mushY,test_size=0.3,random_state=42)
print X_train.shape,y_train.shape,X2_train.shape,y2_train.shape
print X_test.shape, y_test.shape,X2_test.shape,y2_test.shape

clf_train7_3_oa = three_clf.fit(X_train,y_train)
dot_data = StringIO()
dot_data = tree.export_graphviz(clf_train7_3_oa,out_file=dot_data)
graph = pydot.graph_from_dot_data(dot_data.getvalue())
graph.write_png('dt_train70pct_dmax3_oa.png')
oaYpred = clf_train7_3_oa.predict(X_test)

clf_train7_3_x = three_clf.fit(X2_train,y2_train)
dot_data = StringIO()
dot_data = tree.export_graphviz(clf_train7_3_x,out_file=dot_data)
graph = pydot.graph_from_dot_data(dot_data.getvalue())
graph.write_png('dt_train70pct_dmax3_x.png')

#check the accuracy and precision 

xYpred = clf_train7_3_x.predict(X2_test)

print "\nUsing original 21 attributes accuracy is %.3f" % metrics.accuracy_score(y_test,oaYpred)
print "Using extended 112 attributes accuracy is %.3f" % metrics.accuracy_score(y2_test,xYpred)
# Out:
# (5686, 21) (5686,) (5686, 112) (5686,)
# (2438, 21) (2438,) (2438, 112) (2438,)
#
# Using original 21 attributes accuracy is 0.952
# Using extended 112 attributes accuracy is 0.961

# %% [markdown]
# # What about Random Forests?

# %%
from sklearn.ensemble import RandomForestClassifier
rf_clf = RandomForestClassifier(n_estimators=10)
# use above splits to test & train upon
rf_clf.fit(X_train,y_train)
print "Accuracy using original 21 attributes is %.3f" % rf_clf.score(X_test,y_test)

rf_clf.fit(X2_train,y2_train)
print "Accuracy using extended 112 attributes is %.3f" % rf_clf.score(X2_test,y2_test)
# Out:
# Accuracy using original 21 attributes is 1.000
# Accuracy using extended 112 attributes is 1.000

# %%
rf2 = RandomForestClassifier(n_estimators=10,compute_importances=True,max_depth=3)

# %%
rf2.fit(X_train,y_train)
print "Accuracy using original 21 attributes is %.3f" % rf2.score(X_test,y_test)
bar(arange(21),rf2.feature_importances_,color='r')
# Out:
# Accuracy using original 21 attributes is 0.977
# <Container object of 21 artists>

# %%
rf2.fit(X2_train,y2_train)
print "Accuracy using extended 112 attributes is %.3f" % rf2.score(X2_test,y2_test)

bar(arange(112),rf2.feature_importances_)
# Out:
# Accuracy using extended 112 attributes is 0.985
# <Container object of 112 artists>

# %%
rf2 = RandomForestClassifier(n_estimators=100,compute_importances=True,max_depth=3)
rf2.fit(X2_train,y2_train)
print "Accuracy using extended 112 attributes is %.3f" % rf2.score(X2_test,y2_test)

bar(arange(112),rf2.feature_importances_)
# Out:
# Accuracy using extended 112 attributes is 0.989
# <Container object of 112 artists>

# %%
rf2 = RandomForestClassifier(n_estimators=100,compute_importances=True,max_depth=3)
rf2.fit(X_train,y_train)
print "Accuracy using original 21 attributes is %.3f" % rf2.score(X_test,y_test)

bar(arange(21),rf2.feature_importances_,color='r')
# Out:
# Accuracy using original 21 attributes is 0.986
# <Container object of 21 artists>

# %% [markdown]
# ## Define another rule from .names

# %%
#dfine groups using rule P4 habitat=leaves.and.cap_color=white
ruleP4 = mm[(mm.habitat =='l') & (mm.cap_color == 'w')]
notruleP4 = mm[(mm.habitat !='l') & (mm.cap_color != 'w')]
#output resuls
print ruleP4.groupby('tgtclass')['tgtclass'].count()
print "_______________________________"
notruleP4.groupby('tgtclass')['tgtclass'].count()
# Out:
# tgtclass
# p           8
# dtype: int64
# _______________________________
# tgtclass
# e           3248
# p           3012
# dtype: int64

# %%
#create a series of training sizes from 0 to 1
trnsize = 0.05*arange(21)
trnsize

# %%
i=0
for t in trnsize:
    X_train, X_test, y_train,y_test = cross_validation.train_test_split(mushX,mushY,test_size=1-t)
    
    i+=1

# %% [markdown]
# # Create a sample market basket file (csv format)

# %%
ntrans = 1000
maxitemcode = 50
maxitems = 20 # maximum number of items in a transaction
itemsetcodes = arange(1,maxitemcode)
marketbasket = []
for i in xrange(0,ntrans):
    kitems = random.randint(1,maxitems)
    #print i
    transaction = []
    for k in range(kitems):
        jitem = random.randint(1,maxitemcode)
        print jitem,
        transaction.append(jitem)
    print
    marketbasket.append(transaction)
# Out:
# 49 36 28 1 21
# 39 15 48 46 4 8 43 13 29 37 42 40 36 7 37 18 19
# 40 18 20 28 40 31 31 15 32 8 22 19 4 42 32 35
# 16 29 5 21 3 35
# 22 43 1 31 49 47 31 19
# 27 33 20 19 39 45 46 25 47 37 47 49
# 24 49 41 11 31 17 26 19 46 6
# 12 5 48 22 35 30 26 9 17 37 36 26
# 18 11 44 17 23 14 8 28 4 42 34 42
# 17 3 7 41 44 47
# 49 18 27 26 17 7 34 38 44 47
# 47 29 1 45 26 8 40 47 44 47 38 23 12 8 31 48
# 42 12 6 14 12 45 35 21 42 48 36 4 24 3 39 32 12 30
# 6 34 34 6 38 41 10 8 31 1 26 21 48 33 8
# 21 33 6 23 6
# 5 11 32 32 28 7 39 4 43 5 5 41 8 28 46 32 13 12
# 36 42 23
# 14 28 15 22 15 22 48 26 24 19 43 45
# 1 35 26 18 2 21 28 19 1 28 42 42 19 41 45 6
# 4 16 39 4 44 35 47 31 29 19 11 16
# 23 12 44 16 39 1 2 12 24 40 1 3 1 27 17
# 19
# 43 7 11 25 38 30 45 31
# 32 1 28 14 33 41
# 2 41 34 48 35 12 20 2 4
# 28 46 42 15 21
# 31 7 44 9 48 37 43 26 47 6 20 9 32 5
# 26 13 12 30 24
# 25 22 47 22 25 21 26 44 24 17 5
# 13 41 37 8 17 28 3 21 32 17 36 44 38 47 28

# %%
transaction, marketbasket
# Out:
# ([13, 41, 37, 8, 17, 28, 3, 21, 32, 17, 36, 44, 38, 47, 28],
#  [[49, 36, 28, 1, 21],
#   [39, 15, 48, 46, 4, 8, 43, 13, 29, 37, 42, 40, 36, 7, 37, 18, 19],
#   [40, 18, 20, 28, 40, 31, 31, 15, 32, 8, 22, 19, 4, 42, 32, 35],
#   [16, 29, 5, 21, 3, 35],
#   [22, 43, 1, 31, 49, 47, 31, 19],
#   [27, 33, 20, 19, 39, 45, 46, 25, 47, 37, 47, 49],
#   [24, 49, 41, 11, 31, 17, 26, 19, 46, 6],
#   [12, 5, 48, 22, 35, 30, 26, 9, 17, 37, 36, 26],
#   [18, 11, 44, 17, 23, 14, 8, 28, 4, 42, 34, 42],
#   [17, 3, 7, 41, 44, 47],
#   [49, 18, 27, 26, 17, 7, 34, 38, 44, 47],
#   [47, 29, 1, 45, 26, 8, 40, 47, 44, 47, 38, 23, 12, 8, 31, 48],
#   [42, 12, 6, 14, 12, 45, 35, 21, 42, 48, 36, 4, 24, 3, 39, 32, 12, 30],
#   [6, 34, 34, 6, 38, 41, 10, 8, 31, 1, 26, 21, 48, 33, 8],
#   [21, 33, 6, 23, 6],
#   [5, 11, 32, 32, 28, 7, 39, 4, 43, 5, 5, 41, 8, 28, 46, 32, 13, 12],
#   [36, 42, 23],
#   [42, 23, 22, 48, 31, 37, 44, 7, 28, 20, 32, 33, 31, 21, 35, 22, 40, 12, 25],
#   [24, 41, 31, 13, 26, 23, 29],
#   [34, 2, 18, 28],
#   [15, 44, 39],
#   [4, 39, 34, 33, 16, 11, 49, 10, 3, 37, 14, 39, 36, 24, 20],
#   [39, 47, 24, 26, 9, 13],
#   [24, 8, 38, 32, 47, 17, 37, 44, 10, 36, 28, 16, 25, 49, 26, 24, 21, 12],
#   [45, 47, 12, 24, 34, 42, 38, 43, 35],
#   [39, 49, 26, 18, 43, 48, 30, 48],
#   [18, 19, 42, 5, 10, 38, 32, 18, 32, 49],
#   [33, 2, 26, 30, 11, 46, 38, 9, 46, 2, 22, 9, 18, 35],
#   [31, 11, 12, 2, 48, 35, 6, 18, 20, 45, 43, 42, 34, 49, 16],
#   [4, 39, 42, 28, 24],
#   [44, 40, 19, 17, 35, 11, 4, 1, 15, 44, 32, 31, 40, 11, 34, 37, 15],
#   [19, 49, 42, 8, 41, 18, 34, 5, 8, 34, 31, 43],
#   [9, 38, 24, 47, 19, 44, 21, 48, 44, 4, 2],
#   [38, 15, 36, 7, 19, 19, 26, 32, 20],
#   [26, 32],
#   [35],
#   [33, 8, 47, 1, 6, 24, 28, 13, 44, 22, 12, 39, 25, 35, 1, 17],
#   [6, 27, 4, 40],
#   [45, 11, 13, 18, 29],
#   [26, 14, 24, 46, 32, 11, 37],
#   [10, 9, 39, 11, 46, 21, 47, 26, 13, 19, 1, 11, 4, 24, 27, 25, 46, 49, 46],
#   [31, 2, 1, 2, 46, 30, 46, 21, 11, 32, 34, 8, 11, 12],
#   [6, 36, 44, 8, 32, 37, 39],
#   [27, 25, 38, 23, 10, 18, 18, 34, 49, 23],
#   [29, 36],
#   [32, 38, 30, 21, 14, 9, 23],
#   [25, 36, 38, 13, 8, 6, 36, 3, 45, 42, 30, 26, 6, 42, 3, 48, 35, 11],
#   [8, 44, 40, 45, 36, 38, 4, 22, 24, 39, 31, 18, 20, 48, 44, 26],
#   [31, 34, 33, 14, 18, 48, 48, 30, 24, 49, 13, 5, 36, 38, 7, 31, 33],
#   [33, 6, 48, 14, 49, 9, 20, 29, 20, 3, 40, 7, 44],
#   [24],
#   [48, 26, 38, 37, 16, 13, 24, 23, 12, 23, 35, 25, 48, 24, 27, 19],
#   [26, 5, 34, 5],
#   [3, 16, 36, 45, 40, 40, 22, 4, 24, 46, 2, 32, 11, 46, 8],
#   [6, 24, 16, 46],
#   [33, 27, 23, 13, 41, 36, 22, 48, 40],
#   [40, 29, 13, 45, 8, 7, 48, 41, 7, 17, 42, 22],
#   [32, 29, 34, 9, 38, 31, 22, 31, 5, 20, 10, 4, 48, 8],
#   [31, 9, 39, 8],
#   [43, 38, 21, 23, 2, 32, 42, 40, 34, 37, 38, 41, 42, 41],
#   [36, 6, 17, 44, 39, 16, 13, 48, 36],
#   [25, 31, 14, 24, 30, 3, 46, 2, 19, 14],
#   [13, 45, 37, 31, 40],
#   [22],
#   [35, 49, 29, 33, 36, 35, 22, 38, 42, 8, 18, 27, 19, 40, 49, 21, 38, 2, 30],
#   [31, 38, 24, 42, 4, 48, 5, 19, 16, 23, 33, 27, 39, 5, 10, 40],
#   [18],
#   [30, 37, 44, 12, 38, 42, 27, 10, 15, 37, 3],
#   [29],
#   [16, 39, 48, 7],
#   [49, 49, 9, 12, 30, 14, 17, 22, 44],
#   [23, 31, 35, 36, 27, 14, 16, 10, 5, 33, 31, 16, 7, 30, 4, 36, 47, 19],
#   [29, 26, 20],
#   [37, 44, 19, 27, 3, 49, 30, 38, 36, 39, 25, 27, 36, 32],
#   [49, 9, 29, 39, 29, 21, 4, 41, 48, 37, 20],
#   [5, 42, 38, 23, 16, 28, 9, 32, 2, 19, 32, 48, 12, 8, 28],
#   [16, 25, 19, 20, 19, 3, 23, 49, 43, 42, 33, 35, 33, 26, 12, 21, 2, 9, 16],
#   [35, 41, 11, 29, 36, 22, 25, 25, 17, 12, 43, 8, 27, 45, 9, 5, 14],
#   [40, 28, 16, 18, 42, 16, 49, 21, 39, 5, 8, 11, 9, 9, 9, 24, 26],
#   [33],
#   [45, 32, 34, 28, 17, 35, 30, 15, 22, 1],
#   [21, 29, 40, 36, 15, 46, 31],
#   [26, 18, 43, 29, 11, 44, 30, 45, 21, 1],
#   [29, 24, 34, 7, 14, 21, 14, 4, 8, 47, 15, 9, 10, 15, 4, 38],
#   [36, 44, 29, 31, 28, 5, 30, 44, 2, 25, 38, 6, 17, 31, 33],
#   [26, 30, 41, 15, 33, 14, 27, 11, 9, 26, 43],
#   [15, 36, 24],
#   [2, 15, 39, 37],
#   [4, 9, 7, 8, 16],
#   [17, 26, 18, 13, 10, 49, 37, 27, 42, 8, 45],
#   [6, 47, 9],
#   [24, 7, 5, 28, 27, 43, 15, 11, 41],
#   [25, 8, 40, 44, 22, 13, 43, 37, 44, 33, 43, 45, 14],
#   [36],
#   [19, 26, 27, 16, 32, 16, 23],
#   [6, 9, 19, 15, 45, 16, 38, 28, 32, 47],
#   [31, 18, 20],
#   [11, 25, 16, 2, 32, 2, 12, 19, 32, 40, 42, 34, 3, 45, 24, 24, 11, 24, 6],
#   [36, 13, 13, 24, 23, 23, 12, 26, 23, 24],
#   [3, 15, 44, 33, 39, 9, 30, 13, 41, 2, 8, 37, 36, 39, 49, 38, 7, 5, 43],
#   [37, 41, 43, 4, 43, 32, 48, 37, 15, 6, 35, 10, 10, 27, 20, 2, 43],
#   [21, 37],
#   [34, 35, 18, 6, 13],
#   [30, 41, 8, 4, 20, 17, 49, 9, 26, 24, 44, 25, 28, 20],
#   [21, 48, 12, 29, 5],
#   [19, 6, 49, 34, 42, 16, 7, 34, 6, 36, 36, 28, 2, 4, 4, 38],
#   [11, 49, 22],
#   [39, 49, 25, 41, 42],
#   [40, 36, 9, 8, 30, 46, 44, 30, 34, 5, 33, 23, 15, 6, 6, 9, 22, 47],
#   [18, 38, 23, 42, 11, 36, 34, 19, 11, 24, 39, 6, 3],
#   [40, 11, 40, 1, 45, 29, 14, 26],
#   [4, 4, 23, 23, 9, 24, 30, 47, 11, 4, 36, 35, 38, 5, 3],
#   [9],
#   [2, 7, 42, 20, 7, 29, 19, 16, 37, 3, 10, 37, 6, 37, 21, 17, 48, 18],
#   [23, 46, 28, 15, 47, 27, 45, 28, 41, 22, 10],
#   [44, 46, 19, 2, 41, 27, 42, 32, 20, 19, 1, 16, 35, 40, 30, 37],
#   [11, 19, 45],
#   [46, 36, 20, 35, 5, 22, 11, 15, 2, 23, 32, 43],
#   [36, 5, 46, 35, 48, 21, 25, 8, 25, 40, 8, 34, 17],
#   [6, 9, 41, 48, 39, 5, 13, 10, 39, 36, 29, 21],
#   [11, 27, 49, 35, 13, 30, 28, 11, 40, 3, 6, 37, 11, 9],
#   [16, 35, 21],
#   [14],
#   [7, 8, 33, 40, 7, 43, 49, 23, 41, 31, 14, 25, 48],
#   [12, 21, 19, 48, 33, 10, 22, 23, 13, 7, 7, 28, 20, 18, 33, 32, 29, 28, 23],
#   [47, 35, 9, 13, 11, 19, 25, 19, 40, 37],
#   [20, 28, 40, 18, 1, 27, 12, 31, 27, 28, 40, 4, 18, 29, 40, 38],
#   [43, 11, 16, 14, 25, 26, 39, 10, 11, 28, 23, 8, 36],
#   [41, 25, 1],
#   [16, 21, 45, 25, 16],
#   [27, 10, 13, 42, 49, 11, 22],
#   [36, 12, 27, 42, 46, 16, 13, 9, 43, 43, 45, 3, 9, 7, 1],
#   [20, 42, 47, 1, 9, 7, 46, 40, 20, 49, 21, 19, 15],
#   [26, 19, 5],
#   [43, 35],
#   [21, 47, 45, 14, 24, 41, 35],
#   [46, 14, 15],
#   [17, 32, 9, 33, 18, 32, 12, 33],
#   [28, 15, 23, 9, 2, 26, 3, 13, 12, 27, 40],
#   [19, 22, 43, 28, 11, 2, 28, 22, 25, 46, 36],
#   [13, 37, 31, 31, 47, 4, 48, 18, 36, 23, 29, 18, 14, 12, 10, 26, 40],
#   [45, 28, 49, 22, 35, 30, 1, 41, 25, 28, 12, 2, 1, 23],
#   [39, 16, 6, 36, 22, 45, 20, 16, 40],
#   [6, 25, 20, 36, 32, 40, 23, 36, 36, 48, 9, 7],
#   [41, 37, 39, 40, 5, 31, 30, 42, 46, 16, 27],
#   [25, 47, 46, 40],
#   [29, 21, 35, 15, 39, 46, 27, 32, 28, 45, 6, 45, 23, 31, 47, 45, 45],
#   [14, 45, 7, 42, 37, 1, 44, 5, 35, 29, 49, 17, 14, 25, 17],
#   [13, 37, 7, 34, 5, 12, 37, 28, 12, 17, 20, 9, 3, 32, 8, 7, 9],
#   [45, 36, 27, 37, 38],
#   [8, 10, 13, 43, 49, 36, 20],
#   [2],
#   [33],
#   [11, 7, 1, 26, 16, 37],
#   [44, 31, 3, 38, 32, 28, 25, 37, 30, 32],
#   [11, 39, 42, 5],
#   [38, 30, 11, 47, 28, 3, 16, 10, 21, 25, 28, 3, 15, 21, 30, 29, 35, 22],
#   [29, 4],
#   [35, 3],
#   [27, 37, 16, 41, 17, 45, 27, 37, 33, 46, 33, 40, 42, 3, 31, 22],
#   [38, 27, 4, 27, 3, 5, 45, 28, 10, 3],
#   [31, 43, 34, 32, 5, 20, 28, 13, 26, 24, 32, 18, 9, 45],
#   [14],
#   [22, 3, 21, 15, 36, 20, 2, 15, 10, 22, 16, 37, 36, 15],
#   [1, 36, 41, 35, 30, 12, 43, 17, 40, 4],
#   [27, 4, 44, 44, 48, 47, 19, 12, 19, 22, 20],
#   [43, 1, 36, 27, 40, 45, 24, 41, 5, 23, 8],
#   [34, 17, 8, 27, 16, 27],
#   [49, 33],
#   [8, 17, 43, 26, 3, 35, 35],
#   [7, 45, 24, 25, 20, 30, 22, 34, 45, 34, 37, 21, 38, 15, 9, 37, 8, 30],
#   [43, 16, 1, 1, 49, 24],
#   [21, 5, 24, 14, 8, 37, 5, 43, 33, 1, 13, 12, 48],
#   [12, 12],
#   [12, 33, 15, 19, 23, 9, 4, 36, 29],
#   [10, 18, 2, 34, 27, 12, 18, 9, 43, 3, 6, 7, 37, 39, 5],
#   [24, 27, 2, 14, 1, 18, 2, 31],
#   [10, 16, 42, 27, 35, 31, 9, 7, 16, 15, 42, 46, 13],
#   [27, 16, 16, 14, 39, 20, 40, 30, 39, 10, 2, 34, 38, 11, 5],
#   [7, 14, 43, 12, 42, 42, 17, 5],
#   [15, 17],
#   [35, 48, 39, 46, 31, 7, 36, 7, 31, 41, 2, 17, 6, 49],
#   [32],
#   [25, 27],
#   [28, 29, 44, 9, 32, 14],
#   [7, 18, 8, 38, 2, 40, 17, 8, 47, 1, 7, 13, 32, 44, 40, 39, 27, 9],
#   [49, 19, 23, 43, 17, 41, 29, 44, 37, 11, 40, 25, 5, 4],
#   [15, 36, 25, 16, 20, 30, 2, 26, 26, 49],
#   [7, 25, 24, 16, 29, 49, 24],
#   [18, 39, 3, 12, 49, 48],
#   [33, 10, 17, 11, 11, 48, 11],
#   [14, 45, 37, 11, 43, 2],
#   [42, 22],
#   [25],
#   [20, 34, 18, 8, 6, 7, 10, 32, 1],
#   [19, 18, 23],
#   [31, 44, 19, 26, 37, 24, 25, 44, 48, 25, 10],
#   [32, 43, 14, 10, 13, 30, 49, 26],
#   [7, 19, 20, 29, 18, 10, 39, 9, 24, 24, 15, 11],
#   [17],
#   [33, 17, 37, 35, 17],
#   [4, 30, 42, 24],
#   [22, 11, 43, 44, 13],
#   [8, 41, 13, 2, 47, 36, 19, 17, 2],
#   [25, 7, 14, 34, 47, 29, 27, 40, 15, 30, 15, 9, 22, 21],
#   [34, 13, 20, 27, 14, 15, 22, 18, 46, 9, 33, 42, 11, 5],
#   [40, 12, 5, 39, 16, 3, 2],
#   [40, 19, 43, 12, 28, 9, 3, 1, 36, 15, 48, 21],
#   [14, 29, 39, 46, 15],
#   [3, 16, 22, 36, 41, 19, 32, 31, 40, 11, 45, 38, 34, 35],
#   [6, 30, 22, 29, 26, 16, 3, 26, 40, 8],
#   [6, 37, 12, 28, 49, 37, 9, 24, 3, 44, 34, 35, 25],
#   [46, 17, 37, 24, 24, 10, 15, 14],
#   [43, 27, 26, 45, 7, 10, 45, 6],
#   [19, 17, 43, 16, 30, 42, 46, 41, 20, 29, 30, 23, 18, 31, 49, 46, 37, 12, 33],
#   [1, 23, 33],
#   [28, 40, 30, 5, 45, 31, 42, 36, 28, 4, 46, 7],
#   [34, 44, 9, 24, 32, 25, 47, 5, 10, 17, 19, 46, 21, 43, 27, 39],
#   [49, 31, 23, 37, 40, 31, 14, 45, 16, 1, 6, 32, 22, 31],
#   [18],
#   [6, 39, 42, 1, 21, 35, 13, 11, 16, 40, 6, 31, 48, 14, 45, 2, 13, 19, 7],
#   [1, 5, 6, 43, 43, 40, 34, 44, 24, 4, 17, 8, 22, 1],
#   [30, 2, 18, 17, 20, 47, 20, 36, 2, 12, 24, 10, 37],
#   [26, 11, 31, 1, 17, 19, 31, 31, 41, 34, 43, 37, 36, 26, 28, 23, 6],
#   [8, 35, 21, 19, 40, 40, 7, 7, 26, 44, 33, 27, 29, 46, 31, 4, 37],
#   [11, 43, 28, 24, 18, 43, 47, 26],
#   [43, 48, 38, 47, 8, 19, 31, 20, 30],
#   [24, 48, 18, 14, 39, 49, 47, 12, 1, 23, 42, 15, 29, 1, 22, 36, 8, 17, 19],
#   [28, 46],
#   [42, 14, 4, 48, 46, 43, 11, 36, 27, 1],
#   [34, 42, 33, 32, 46, 9, 34, 48, 22, 5],
#   [32, 17, 32, 27, 43, 37, 18],
#   [29, 28, 16, 31, 30, 18, 16, 10, 47, 35, 13],
#   [5, 18, 34, 5, 49],
#   [39, 31, 1, 29, 7, 18, 12, 24, 30, 23, 21, 48, 16],
#   [1, 45, 46, 48, 13, 19, 11, 45, 2, 40, 33, 25, 28, 21, 6],
#   [43, 13, 42, 36, 34, 30, 33, 48, 4, 37, 27],
#   [17, 25, 20, 40, 30, 2, 45, 5, 41, 14, 46, 24, 8],
#   [3, 8, 2, 47, 24, 34, 6, 2, 43, 21],
#   [47, 19],
#   [16, 39, 37, 15, 31, 8, 33, 11, 42, 9, 46, 29, 45, 8],
#   [39, 16, 23, 5, 17, 40, 19, 31, 34, 36, 12, 28, 27, 11, 43, 14, 13, 14, 19],
#   [33, 15, 43, 24, 26, 24, 43, 19, 45, 27, 29, 30, 35, 29],
#   [12, 39, 19, 23, 39, 27, 16, 31, 39, 3, 9, 33],
#   [44, 33, 4],
#   [3, 35, 19, 11],
#   [3, 15, 10, 4, 23, 28, 42, 8, 32, 24, 21, 9, 48, 44, 34, 34, 23, 17, 41],
#   [39, 47, 17, 37, 34, 45, 37, 20, 42, 36],
#   [16, 25, 22],
#   [11],
#   [37, 19, 44, 12, 5, 27, 39, 22, 26, 28, 33, 46],
#   [33, 40, 41, 41, 47, 40, 49, 46, 7, 35, 12, 35, 31, 12, 41, 30, 24, 40, 37],
#   [19, 18, 23, 37, 5],
#   [5, 32, 46, 33, 7, 8, 1, 23, 3, 37, 24, 37, 41, 30, 19, 30, 11],
#   [43, 27, 45, 30, 36, 12, 45, 7, 6, 38, 15],
#   [36, 22, 38],
#   [49, 4, 3, 24],
#   [15, 42, 4, 44, 44, 34, 49, 29, 18, 29, 40, 40, 2, 45],
#   [23, 6, 47, 9, 22, 16],
#   [33, 20, 25, 42, 25],
#   [30, 48, 24, 24, 21, 30, 20, 5, 29, 12, 26, 25, 26],
#   [10, 36, 6, 38, 16, 4, 20, 49, 17, 20, 11, 5, 17, 38, 39, 19],
#   [49, 46, 20, 14, 27, 23, 8, 45, 39, 10, 33, 35, 38, 48, 45, 12, 27, 23, 35],
#   [16, 14, 4, 3, 19, 41, 34, 35],
#   [44],
#   [31, 1, 12, 16, 23, 36, 24, 25, 44, 38, 15, 37, 33],
#   [15, 48, 21, 16],
#   [41, 31, 49, 5, 48, 29, 38, 27, 18, 38, 35, 4, 28, 4, 33, 14],
#   [27, 18, 27, 14, 22, 27, 36],
#   [26, 33, 42, 38, 27, 48, 39, 22, 17, 47, 28, 45, 20, 11, 39, 5],
#   [15, 30, 22, 23, 34, 41, 1, 15, 4, 5, 37, 32, 45, 9, 3],
#   [23, 34, 12, 23, 20, 14, 3, 3, 10, 36, 32, 26, 32],
#   [17],
#   [10, 42, 18, 49, 17, 49, 27, 28],
#   [29, 22, 15, 45, 47, 9, 42, 33, 39, 17, 21, 49, 3, 27, 2, 37],
#   [40, 26, 42, 33, 41, 29, 20, 3, 34, 11, 41, 2, 41, 23],
#   [33],
#   [44, 47, 48, 8, 5, 43, 41, 36],
#   [13, 24, 3, 6, 23, 34, 13, 8, 33, 46, 12, 45, 21, 40, 23],
#   [5, 40, 36, 23, 49, 21, 30, 35, 29, 33, 2, 6, 49, 19, 15, 5, 32, 22],
#   [29, 2, 2, 35, 34, 20, 12, 5, 11, 40, 42, 36, 18, 44],
#   [40, 28, 21, 9, 43, 6, 3, 19, 39, 39, 13, 12, 14, 25, 7, 7],
#   [12, 40, 29, 48, 26, 2, 13, 43, 2, 23, 10, 28, 39],
#   [24, 33, 33, 34, 25, 45, 42, 16, 38],
#   [44, 18, 6, 10, 40, 6, 12],
#   [8, 8, 31],
#   [28, 38, 44, 18, 21],
#   [34, 46, 22, 42, 7, 11, 21],
#   [33, 27, 14, 9, 12, 19, 8, 7, 45],
#   [8, 9, 11, 42, 3, 22, 45],
#   [49, 5, 18, 23, 31, 4, 25, 9, 39, 36, 32, 18, 12, 21, 17, 21, 12],
#   [1, 1, 38, 40, 20, 21, 17, 13, 49, 19, 2],
#   [38, 10, 2, 29, 47, 26, 6, 23, 43, 7, 24, 19],
#   [43, 18, 39, 29, 47, 22, 11, 19, 14, 44, 46, 11, 36, 37, 48, 45, 12],
#   [19, 7, 29, 38],
#   [6, 23, 31, 17, 41, 7, 25, 33, 42, 43, 37, 45, 2, 16, 36, 43, 1, 26],
#   [1, 9, 46, 28, 28, 47, 15, 14, 4, 7, 7, 20, 35, 13, 10, 14],
#   [16, 7, 16, 11, 37, 24, 5, 1, 38, 34, 17, 26, 8, 11, 12, 6, 30],
#   [11, 31, 22, 34, 4, 8],
#   [15, 5],
#   [13, 14, 29, 5],
#   [49, 35, 13, 32, 6, 18, 13, 13, 7, 8, 23, 26, 27],
#   [30, 26, 3],
#   [24, 9, 5, 22, 9, 38, 37, 36, 18, 29, 26, 22],
#   [37, 38, 38, 43, 48, 41, 45, 42, 17, 32, 22],
#   [10, 33, 9, 19, 44, 42, 1, 43, 35, 25, 47],
#   [22, 43, 45, 19, 36],
#   [1, 9, 17, 16, 32, 15, 3, 18, 18],
#   [9, 14, 49, 45, 37, 47, 6, 18, 46, 40, 48, 16, 28, 47, 2, 45],
#   [17, 47, 34, 3, 46, 20, 3, 36, 14, 21, 2, 43, 44],
#   [9, 10, 34, 27, 34, 29, 37, 27],
#   [4, 33],
#   [35, 35, 16, 42, 45, 43, 41, 32],
#   [33, 29, 6, 15, 32, 10, 16, 9, 13, 27, 18, 36, 49, 17],
#   [46, 28, 16, 17, 17, 5, 15, 4],
#   [47, 33, 38],
#   [23, 33, 40, 34, 38, 2, 44, 45, 15, 48, 12, 45],
#   [5, 15, 11, 2, 42, 30],
#   [13, 30, 18, 6, 17, 23, 18, 22],
#   [45, 30, 46, 23, 28, 28, 20, 26, 46, 8, 22],
#   [22, 44, 41],
#   [49, 19, 45, 19, 13, 19, 2],
#   [27, 30],
#   [34, 41, 6, 34, 48, 29, 33, 3, 39, 36, 9, 43, 5, 7, 11, 21, 3, 34],
#   [48, 48, 39, 33],
#   [36, 38, 24, 15, 3, 8, 49, 30, 34, 28, 26, 26, 5, 43, 48, 18],
#   [38, 8, 5],
#   [22, 42, 28, 10, 21],
#   [43, 27, 24, 30, 34, 15, 46, 34, 27, 34, 20, 32, 39, 3, 44, 20, 41, 8],
#   [18, 9, 23, 11, 4, 25, 23, 5, 36, 27, 7, 46, 2],
#   [24, 4],
#   [28, 25],
#   [39, 23, 49, 6, 36, 23, 44, 40, 25, 10, 7, 9, 37],
#   [12],
#   [25, 2],
#   [29, 49, 42, 34, 42, 43, 38, 22, 48, 7, 16, 31, 13, 43, 31],
#   [17, 31, 29, 40, 23],
#   [17],
#   [23, 42, 14, 6, 36],
#   [10, 40, 2, 32, 37],
#   [29, 35, 17, 20, 6, 37, 46, 46, 32, 21, 16, 18, 21, 39, 7, 10, 46],
#   [43, 15, 33, 23, 6, 43, 16, 1, 15, 22],
#   [32, 16, 44, 24, 18, 11, 1, 41, 22, 40, 5, 42, 21, 12, 20, 46, 32, 18, 44],
#   [29, 7, 17, 19, 4, 17, 7, 10, 42, 4, 35, 25, 7],
#   [19, 20, 36, 22, 37, 43, 19, 6, 14, 42, 37, 22, 34, 16],
#   [14, 29],
#   [12, 6, 28, 1, 20, 43, 32, 21, 23, 47, 22, 43, 21, 15, 31],
#   [35, 25, 46, 49, 4, 17, 13, 19, 24, 12, 17, 36, 8, 48, 19, 31, 17, 12],
#   [17, 44, 47, 29, 44, 38, 33, 9, 1, 11, 5, 13, 8, 39, 14, 26, 21, 23, 23],
#   [30, 12, 14, 30, 46, 24, 17, 31, 42, 29, 15],
#   [39, 35, 38, 47, 19, 20, 34, 11, 11, 24, 27],
#   [12, 48, 43, 11, 26, 25, 20, 2, 42, 27, 31, 7, 14, 38, 4, 33, 37],
#   [16, 11, 32, 1, 31, 43, 6, 32, 7, 12, 36, 35, 17, 4, 42, 35, 26, 38, 31],
#   [13, 13, 13, 38, 6, 46, 36, 35],
#   [14],
#   [8, 2, 20, 43, 42, 24],
#   [30, 7, 41, 29, 26, 4, 23],
#   [3],
#   [18, 1, 46, 46, 41, 33, 32, 9, 23, 36, 25, 49, 8, 34],
#   [41, 46, 46, 6, 13, 2, 11, 44, 9, 39, 28, 28],
#   [45, 42, 29, 8, 30, 8],
#   [46, 5, 1, 7, 49, 16, 7, 17, 32, 49, 29],
#   [20, 47, 27, 43, 39, 14, 49, 18, 21, 2, 9, 7, 7, 39],
#   [22, 24, 37, 13, 17],
#   [25, 39, 44, 4, 20, 25, 40, 30, 38, 34, 27, 15, 15],
#   [7, 2, 18, 29, 29, 30, 46, 21, 21, 32, 14, 6, 37, 49, 9, 23, 48],
#   [20, 41, 4],
#   [13, 41, 44, 49, 10],
#   [24, 11, 35, 22, 42],
#   [6, 2, 27, 24, 15, 33, 15],
#   [11, 32, 41, 48, 28, 37, 41, 4, 40, 8, 16, 9],
#   [37, 42, 11, 8, 23, 7, 6, 35, 9, 44, 39, 19, 34, 31],
#   [17, 4, 3, 19, 33, 31, 10, 7, 30, 45, 37, 40, 42, 16, 29, 3, 12, 31, 48],
#   [40, 29],
#   [28, 18, 17, 25, 41, 9, 16, 46, 45, 29, 41, 5],
#   [17, 10, 26],
#   [4, 43, 23, 21, 20, 8],
#   [16],
#   [8, 5],
#   [5, 39],
#   [32, 10, 17, 29, 44, 15, 12, 10, 6, 20, 45],
#   [19, 45, 5, 49, 36, 48, 11, 2, 16, 9, 16, 44, 16, 45, 33],
#   [20, 18, 10, 31],
#   [6, 23, 44, 3, 48],
#   [1, 20, 17, 30, 12, 18, 29, 32, 38, 32, 5, 27, 36, 10, 47, 35, 6],
#   [43, 15, 9, 33, 14, 24, 46, 6, 44, 4, 8, 37, 5, 13],
#   [44, 32, 27, 48],
#   [18, 45, 15],
#   [33],
#   [33, 37, 38, 32, 13, 24, 47, 17, 18, 21, 31, 23],
#   [19, 10, 30, 8, 48, 47, 26],
#   [36, 49, 37, 40, 33, 44, 43, 22, 47],
#   [45, 21, 35],
#   [23, 44],
#   [2, 30, 30, 47, 22, 29, 33, 11, 46, 48, 40, 4, 29, 28, 42, 43, 27, 18],
#   [25, 36, 7],
#   [46, 41, 35, 42, 28, 38, 48, 30, 15, 20, 1, 46, 22, 42, 18],
#   [25, 43, 6, 8, 11, 14, 4, 40, 18, 20],
#   [48, 45, 16, 29],
#   [40, 17, 39],
#   [33],
#   [21, 38, 17, 23, 49, 39, 43, 9, 18, 17, 43, 9, 33, 4, 43],
#   [32, 29, 4, 38, 47, 13, 27],
#   [31, 25, 26, 24, 9, 13, 37, 37, 41, 5, 3, 33, 25, 21, 11, 41, 46, 12, 40],
#   [2, 11, 14, 34, 32, 30, 27, 22, 15, 44, 23, 48, 47, 31, 46, 28, 41, 12, 31],
#   [48, 43, 13, 17, 30, 23, 39, 20, 45, 38, 10, 15, 11, 34, 46, 16, 15, 45],
#   [30, 35, 26, 11, 25],
#   [1, 45],
#   [29, 23, 4, 32, 13, 39, 6, 28, 25, 46, 48, 31, 8, 29, 14, 39, 13, 19, 30],
#   [46, 46, 20, 46, 31, 13, 26, 41, 44],
#   [20],
#   [43, 1, 3, 31, 20, 18, 24, 15, 34, 2, 38, 41, 10, 27, 14, 29],
#   [2, 16, 5, 7, 24, 41, 4, 16, 44, 39, 20, 25, 6, 37, 27, 8],
#   [40, 7, 28, 46],
#   [4, 49, 11, 17, 16, 29, 16, 30, 12, 25],
#   [31, 35, 39],
#   [12, 46, 15, 5, 2, 11, 44, 32, 45, 5, 24, 35, 32, 45],
#   [44, 44, 37, 7, 25, 25, 24],
#   [28, 26, 17, 17, 48, 11, 14, 14, 39, 3, 42, 42, 42, 23, 3, 48, 32, 11, 26],
#   [45, 7, 22, 25, 5],
#   [42, 47, 30, 16, 28, 29, 18, 32, 40, 30, 24, 42, 20, 24, 14, 4],
#   [33, 10, 5, 2, 4, 44, 17, 26, 15],
#   [6, 28, 24, 11, 7, 8, 35, 13, 8, 48, 15],
#   [7, 49, 46, 40, 30, 14, 4, 9, 32, 42, 8, 26, 27],
#   [27, 19, 10, 20],
#   [32, 39, 31, 48, 9, 21, 10, 31, 11, 40, 45],
#   [4, 29, 12, 18, 28, 35],
#   [29, 20, 22, 20, 10, 47, 34, 24, 45, 25, 21, 46, 24, 41, 20, 15, 16],
#   [35, 36, 46, 15, 17],
#   [34, 7, 24, 48, 1, 34, 44, 27, 18, 5, 21, 9, 48, 37, 44, 46],
#   [22, 32, 34, 27, 5, 33, 36, 41, 44, 49, 36, 37, 32],
#   [2, 5],
#   [3, 47, 3, 31, 7, 33, 8, 7, 34, 23, 39, 10, 14, 33, 38, 32, 35, 25, 23],
#   [15],
#   [6, 6, 22, 14, 41, 25, 21, 37, 23, 27, 47, 26, 43, 11, 2, 11],
#   [49, 1, 16],
#   [31, 27, 32, 33, 26, 9, 24, 1, 40, 48, 34],
#   [22, 43, 3, 26, 6, 46, 6, 43, 27, 35, 44, 2, 3, 31, 30, 18, 19, 37, 21],
#   [7, 3, 48, 4, 1, 37, 46],
#   [7, 25, 36, 43, 8, 4, 26],
#   [14, 17, 32, 11, 42, 20, 3, 2, 3, 4, 41, 38, 14, 22, 13, 38, 31, 21, 10],
#   [3, 40, 21, 16, 36, 49, 2, 11, 45, 48, 5, 47, 33, 49, 35, 15, 33],
#   [18, 13, 44, 22, 26, 48, 42, 8, 49, 17, 45, 49, 12, 49, 41, 27],
#   [47, 32, 1, 5, 49, 38, 20, 30, 28, 24, 23, 33, 29, 27, 26, 29, 39, 42],
#   [2],
#   [10, 42, 30, 41, 19, 6, 15],
#   [11, 32, 29, 32, 38],
#   [18, 11, 22, 6, 27, 24, 7, 25, 27, 7, 43, 41, 1],
#   [43, 34],
#   [44, 32, 42, 2, 28, 10, 7, 15, 35, 9, 23, 34, 42, 31, 3],
#   [5, 20, 38, 29, 31, 31, 45, 43, 2, 24],
#   [39, 21, 26, 29, 1, 47, 29, 6, 15, 26, 7, 2, 12, 3],
#   [22, 15, 22],
#   [4, 18, 13, 35, 14, 23, 34, 24, 21, 10, 36, 4, 6, 45, 36],
#   [12, 33, 21, 42, 9, 35, 5, 24],
#   [7, 18, 10, 35, 15, 25, 48, 43, 32, 42, 13, 48, 21, 40, 48, 30],
#   [40, 31, 42, 1, 38, 42, 31, 27, 28, 29, 31, 40, 45, 45, 25, 40, 31, 21],
#   [21],
#   [47, 17, 31, 27, 42, 41, 29, 27, 2, 21, 44, 7, 4, 30, 19, 33, 14],
#   [14, 3, 44, 44, 9, 31, 33, 35, 3],
#   [12, 35, 8, 46, 13, 35, 25, 3, 43, 8, 4, 37, 21, 27, 6, 3, 1],
#   [41, 15, 23, 46, 36, 2, 19, 37, 41, 38, 13, 26],
#   [21, 49, 14, 47],
#   [26, 13, 2, 21, 46, 42, 45, 10],
#   [23, 32, 28, 10, 27, 20, 18, 16, 39, 8, 16, 46, 15, 37, 28, 14, 19],
#   [9, 11, 14, 47, 35, 12, 17, 8],
#   [19, 2, 30, 26, 11, 10],
#   [36, 34, 26, 14, 31, 42],
#   [2, 31, 40, 2, 41, 45, 27, 1, 11, 11, 46, 46, 43, 7, 47],
#   [11, 23, 45, 32, 29],
#   [30, 42, 6, 35, 12, 31, 26, 26, 11],
#   [47, 25, 46, 48, 22, 41, 6, 40, 12, 10, 27, 18, 30, 43, 20, 3],
#   [4, 44, 30, 8, 7, 7, 37, 18, 48, 10],
#   [34, 34, 23, 39, 25],
#   [34, 19, 19, 21, 43, 33, 19, 37, 45, 19, 27, 19],
#   [36, 22, 39, 18, 16, 39, 22],
#   [22, 40, 38, 43, 3, 31, 36, 42, 46, 26, 21, 47, 1, 2, 3],
#   [38, 17, 48, 40, 39, 39, 14, 39, 30, 1, 28, 13, 1, 11, 10, 3],
#   [48, 30, 18, 38, 40],
#   [37, 16, 11, 2, 21, 48, 14, 19, 16, 15, 45],
#   [31, 13, 7, 31, 18, 6, 6, 42, 4, 27, 45, 4, 13, 19],
#   [36, 22, 19, 25, 48, 23],
#   [44, 39, 42, 35, 22, 15, 36, 18, 7, 4, 31, 44],
#   [43, 23, 6, 10],
#   [8, 5, 31, 21, 42, 41],
#   [48, 5, 10, 49, 44, 11, 11, 37, 20, 2, 15, 34],
#   [24, 36, 47, 47, 19, 18, 32, 31, 34, 33, 40, 13, 6, 7, 45, 18],
#   [22, 33, 35, 6, 2, 20, 32, 4, 23, 45, 7, 7, 27, 8, 40],
#   [29, 4, 27],
#   [16, 29],
#   [2, 35, 5, 49, 26],
#   [5, 14, 42, 38, 37, 11, 3, 47, 21, 39, 46, 11, 22, 11, 44],
#   [26, 3, 33, 15, 5, 29, 41, 21, 23, 11, 2, 3, 48],
#   [37, 5, 24, 15, 4, 12, 14],
#   [2, 8],
#   [26, 2, 48, 43, 2, 21, 49, 37, 13, 48, 7, 25, 35, 34, 44, 12, 23],
#   [10, 27, 4, 9, 9, 22, 20, 47, 9, 37, 22, 6],
#   [3, 25],
#   [21, 43, 22, 20, 48, 9, 22, 18, 39, 47, 5, 44],
#   [2, 32, 26, 3, 47, 7, 27],
#   [22, 14, 29, 16, 34],
#   [14, 12, 32, 3, 9, 2, 24, 16, 25, 41, 38, 42, 19, 49],
#   [15, 31, 5, 12, 27, 19, 42, 37],
#   [49, 40, 27, 25, 24, 32, 41, 8, 47, 32, 44, 1, 31, 9, 10],
#   [45, 17, 34, 26, 33],
#   [1, 29, 14, 19, 27, 5, 7, 35, 41, 42, 14, 36, 12, 7, 33, 7, 28, 28, 44],
#   [21, 25, 7, 35, 27, 32, 36, 38, 33, 12, 32, 10, 6, 46, 43, 43],
#   [28, 34, 20, 3, 23, 6, 26, 2],
#   [19, 22, 44, 5, 49, 40, 12, 38, 45, 30, 7],
#   [47, 45],
#   [14, 13, 4, 27, 24, 35, 42, 20, 23, 40, 25, 5, 20],
#   [44, 41, 26, 27, 48, 32, 48, 28, 49, 24, 12, 46, 17, 17],
#   [28, 14, 32, 18, 19, 45, 27, 13, 33, 48, 19],
#   [15, 27, 19, 29, 48, 17, 44, 37, 48, 43, 34, 15, 24, 4, 2, 35, 1, 19, 6],
#   [14, 4, 17, 31, 28, 3, 17, 18, 20, 7, 40, 48, 4, 45, 4, 42, 35, 2],
#   [21],
#   [5, 1, 41, 42, 32, 38, 26, 19, 29, 14, 4, 27, 23, 29, 30, 45, 11, 18, 29],
#   [11, 2, 35, 41, 30, 42, 43, 38, 7, 33, 27, 49, 19, 33, 38, 27, 11],
#   [41, 10],
#   [25, 2, 40, 24, 42, 5, 44, 32, 33, 20, 45, 39, 23, 44],
#   [36, 18, 20, 44, 7, 23, 31, 13, 37],
#   [21, 24, 33, 2, 1, 17, 37, 34, 48, 18, 4],
#   [39, 4, 22, 36, 13, 46, 32],
#   [18, 47, 15, 19, 21, 42, 28, 40, 20, 39, 23, 40, 21, 49, 14, 10, 30, 19, 39],
#   [7, 33, 13, 47, 36, 23, 16],
#   [30, 32, 42, 31, 23],
#   [17, 6, 9, 49],
#   [34, 42, 12],
#   [8, 47, 46],
#   [19, 30, 19, 20, 40, 27, 21, 19, 22, 4, 38, 25, 23, 43, 36, 49, 39, 15],
#   [44, 17, 4, 5],
#   [18, 7, 25, 46, 25, 39, 10, 18, 41, 3, 41, 34, 19],
#   [12, 7, 48, 18, 20, 14, 37, 33, 33, 2, 32, 21, 46, 31, 16, 44],
#   [12, 3, 45, 34, 18, 7, 37, 8, 15, 11, 44, 26, 25, 14, 47, 36, 45, 5, 14],
#   [20, 25, 31, 17, 45, 32],
#   [49, 6, 26, 37, 20, 36, 2, 39, 36, 7, 16],
#   [2, 12, 22],
#   [11],
#   [21, 27, 49, 28, 17, 30, 27, 12, 23, 34, 20],
#   [47, 3, 26, 24, 30, 27, 34],
#   [49, 38, 17, 21, 2, 7, 35],
#   [22, 22, 40, 20, 15, 20, 7],
#   [16, 30, 49, 5, 32, 42, 44, 41, 42, 4, 15, 41, 8, 4, 23],
#   [29, 1, 22, 33, 25, 4, 39, 18, 44, 46],
#   [49, 26, 49, 34, 31, 18, 23, 18, 16, 38, 10, 21, 21],
#   [28, 31, 39, 24, 9, 43, 33, 39, 1, 31, 46, 23, 20, 20],
#   [34, 38, 7, 48, 48, 33, 13, 40],
#   [10, 14, 24, 9],
#   [27, 49, 34, 41, 21, 3],
#   [45, 23, 1, 44, 40, 10, 20, 8, 19, 35, 19, 19, 22, 48],
#   [20, 44, 28, 40, 38, 37, 30, 21, 33, 26, 5, 15, 31, 14, 20, 5, 34],
#   [30, 48, 9, 18, 38, 16, 8, 30, 42, 19, 43, 19, 18, 27, 4, 40],
#   [26, 17, 49, 26, 43, 48, 29, 39, 33, 48, 10],
#   [18, 27, 35, 44, 46, 29, 10, 14, 44, 6, 45, 9, 12, 42, 10, 22],
#   [12, 39, 46, 39, 19, 33, 37, 5, 39, 19, 19, 15, 25, 26, 9, 8],
#   [34, 42, 1, 31, 2, 19, 1, 20, 37, 22, 25, 8, 6, 9, 26, 30, 8, 32],
#   [12],
#   [30, 17, 48, 3, 37],
#   [39, 15, 48, 35, 20, 28, 47, 37, 26, 41, 49],
#   [13, 47, 49, 17, 11],
#   [42, 43, 41, 2, 13, 2, 9, 32, 37, 48, 27, 9, 21, 10, 32, 23, 5, 37],
#   [39, 25, 29],
#   [27, 2, 11, 7, 14, 26, 14, 36, 21, 16, 7, 30, 23],
#   [7, 19, 36, 15, 11, 46, 38, 42],
#   [5, 27, 20, 34, 14, 7, 7, 29],
#   [26],
#   [15, 32],
#   [5, 39],
#   [36, 23, 37, 28, 48, 10, 22, 47, 6],
#   [27, 49, 36, 39, 21, 6, 10, 12, 41],
#   [46, 35, 15, 47, 25, 43, 39, 11, 23, 17, 10, 33, 15, 9, 45, 4, 14, 13, 40],
#   [4, 43],
#   [25, 16, 40, 15, 30, 24, 6, 29, 17, 3, 18, 29, 27, 39, 36, 13, 8],
#   [47, 14, 6, 16, 15, 22, 34, 11, 8, 2],
#   [25, 30, 22, 7, 37, 26, 14, 42, 36, 4, 24, 48, 39, 26, 37, 12, 10, 42],
#   [36, 20, 8, 25, 32, 42, 17, 36, 28, 38, 8, 5, 36, 25, 18, 3, 47],
#   [33, 6, 28, 19, 32],
#   [43, 6, 44, 1, 29, 41, 10, 46, 18],
#   [17, 19, 31, 5, 22, 24, 23, 39, 1, 18, 7, 3, 28, 35, 19, 35, 45],
#   [45, 41, 27, 33, 1, 6, 12, 6, 10, 39, 7, 28, 3, 13, 25, 13, 3, 4, 15],
#   [3, 29, 35],
#   [1, 10],
#   [27],
#   [10, 31, 28, 13, 33, 43, 4, 36, 49, 38],
#   [4, 7, 30, 39, 16, 47, 1, 15, 36, 9],
#   [40, 18, 35, 2, 40, 34, 6, 6, 26, 1, 48, 35, 32, 16, 17, 40],
#   [46, 44, 38],
#   [24, 26, 3, 37, 42, 39, 14, 21, 27, 23, 7, 40, 10, 3, 8, 43, 9],
#   [17, 31, 8, 26, 27, 23, 14, 48, 11, 20, 11, 40, 26],
#   [23, 19, 22, 38, 28, 14, 33, 29, 25, 5, 1],
#   [29, 7, 25, 17, 14, 48, 13, 49, 41, 48, 38],
#   [13, 49, 38, 36, 37, 18, 30, 49, 23, 20],
#   [37, 25, 27, 16, 26, 19],
#   [34, 22, 48, 22, 14, 27],
#   [21, 17, 33, 9],
#   [2, 47],
#   [29, 49, 20, 4, 30, 12, 4, 35, 18, 28, 32, 13],
#   [22, 6, 11, 29, 13],
#   [22],
#   [40, 35, 34, 13, 5, 41, 22],
#   [32, 12, 4, 6, 26, 48, 13],
#   [48, 16, 42, 45, 20],
#   [13, 27, 1, 19, 8, 43, 28, 27, 20, 23, 44],
#   [43, 33, 39, 16, 47],
#   [12, 38, 18, 3, 33, 18, 19, 31, 4, 9, 42, 38, 21, 20, 22],
#   [32, 41, 42, 23, 31, 47, 39, 1, 25],
#   [18, 8],
#   [26, 16, 18, 13, 39, 16, 20],
#   [43, 6, 8, 43, 8, 42, 6, 7, 10, 23, 16, 13, 22, 20, 36],
#   [46, 36, 25, 5, 46, 24, 1, 15, 43, 44, 38, 9, 8, 49, 21, 6, 30],
#   [25, 23, 8, 36],
#   [4, 36, 30, 44, 49],
#   [35, 20, 26, 47, 20, 17, 8],
#   [16, 23, 1, 31, 26, 21, 6, 10, 29, 18, 34, 10],
#   [20, 39, 4, 19, 4, 1, 6, 23, 39, 30, 37],
#   [11, 43, 26, 16, 44, 14, 5, 2, 5, 18, 21, 26, 38, 40, 14, 34],
#   [30, 22, 21, 32, 25, 21, 24, 16, 45, 40, 7, 35, 22],
#   [11, 12, 27, 4, 32, 13, 11, 7, 49, 40, 25, 18],
#   [23, 37, 25, 6, 9, 27, 44, 38, 18, 3, 19, 41, 5, 18, 3, 10, 11, 41],
#   [29, 41, 17, 48, 41, 6, 43, 33, 13, 9, 20, 28, 15, 34, 16, 40, 16, 38],
#   [35, 38, 2, 17, 33, 46, 29, 44, 39],
#   [37, 31, 39, 9, 11, 22, 3, 42, 48, 49, 36, 29, 7, 37, 26, 38, 34, 41],
#   [23, 15, 21, 29, 14, 42, 1, 14, 8, 8, 7, 41, 14, 6, 48, 36, 13],
#   [41, 11, 28, 16, 45, 16, 1, 19, 9, 7, 4, 46, 37],
#   [27, 35, 44],
#   [15, 27, 17, 16, 22, 7, 21, 3, 30, 7, 33, 6, 1, 41, 32, 45, 45, 19, 18],
#   [6, 22, 26, 36],
#   [15, 34, 34, 25, 35, 45, 9, 13, 39, 32],
#   [47, 11, 46, 38, 38, 17, 21, 35, 17, 44, 37, 30, 6, 44, 23, 12, 15],
#   [9, 31, 40, 13, 37],
#   [35, 46, 31, 3, 47, 46, 43, 41, 47, 19, 33, 18, 3, 39, 44, 16],
#   [47, 43, 28, 37, 9, 17, 31, 22],
#   [48, 31, 5, 5, 28, 30, 39, 1, 45, 44, 23, 7, 49, 47, 46, 44, 42],
#   [44, 43],
#   [22, 9, 37, 23, 37, 32, 9, 9, 29, 16, 5, 21, 49, 19, 15, 24, 25],
#   [42],
#   [30, 19, 48, 16, 41, 8, 1, 8, 25, 32, 3, 43, 9, 33],
#   [1, 46, 7, 23, 23, 30, 43, 27, 14, 17, 1, 44, 16, 4, 16],
#   [47, 36, 45, 44, 9, 37, 21, 31, 4, 3],
#   [24, 34, 5, 46, 9, 31, 33, 31, 49],
#   [22, 47, 15, 11, 14, 37, 29, 44, 2, 35, 47, 13, 38, 27, 22, 45],
#   [44, 49, 13, 21, 46, 48, 37, 43, 19, 30, 28, 39],
#   [19, 4],
#   [25, 22, 29, 47, 25],
#   [40, 46, 35, 23, 36, 19, 32, 1],
#   [20, 43, 11, 6, 18, 18, 6, 6, 42, 17, 41, 25, 22, 47, 45, 2],
#   [43],
#   [34, 38, 47, 1, 24, 44, 11, 27, 12, 20, 33, 41, 46],
#   [18, 33, 6, 16, 24, 41],
#   [44, 37, 28, 33, 30, 21, 12, 46, 39, 24],
#   [43, 12, 35, 1, 6, 18, 44],
#   [4, 32, 41, 13, 33, 26, 45, 16, 42, 21, 27, 10, 40, 32, 40, 3],
#   [40, 26, 35, 3, 5, 27, 25, 38, 44, 47, 34, 31, 29, 44, 34],
#   [13, 10, 10, 34, 22, 49, 16, 21, 34, 23, 27],
#   [28, 39, 26, 27, 4, 17, 3, 7, 39, 48, 6],
#   [29],
#   [6, 30, 41, 3, 18, 4, 31, 14, 33, 4, 14, 1, 47, 34, 6, 46, 35, 22, 13],
#   [49, 2, 16, 22, 44, 3, 45, 4, 2, 4, 39, 9],
#   [1, 48, 2, 27, 6, 14, 9, 22, 49, 34, 31, 1, 24, 30, 26, 10, 23, 21, 44],
#   [42, 9, 16, 30, 25, 23, 32],
#   [43, 47, 35, 37, 1, 4, 24, 24, 13, 25, 30, 1, 5, 12, 37, 22, 32, 48],
#   [7, 15, 9],
#   [39, 20, 17, 17, 43, 42, 42, 1, 6, 48, 3, 19, 28, 1, 27, 3, 5, 20, 13],
#   [18, 46, 9, 16, 45, 27, 11, 16, 21, 19, 30, 38, 1, 2, 38, 30, 43],
#   [41, 20, 37, 7, 27, 47],
#   [28, 34, 6, 8, 43, 44, 28, 40, 15, 1, 46, 15, 1],
#   [9, 36, 20, 32, 48, 35, 7, 19, 17, 3, 26],
#   [39, 41, 11, 46, 13, 39, 23, 34, 7, 30, 26],
#   [3, 27, 9, 45, 17, 2, 26, 32, 26, 26, 44, 35, 18, 30, 43, 47, 30, 36],
#   [17, 48],
#   [29, 15, 15, 35, 37, 27, 21, 6, 16, 4, 30, 9, 32, 46],
#   [20, 10, 1, 36, 49, 17, 10, 48, 42],
#   [23, 10, 1, 40, 17, 48, 48],
#   [38, 42, 1, 34],
#   [11, 42, 34, 10, 29, 49, 22, 19, 28],
#   [49, 11, 21, 20, 13, 7, 24, 43, 21, 34, 4, 46, 43, 39, 49, 32, 9, 24],
#   [29, 12, 19, 21, 44, 11, 9, 18, 23, 13],
#   [32, 22, 42, 34, 27, 7, 2, 20],
#   [40, 37, 46, 33, 33, 43],
#   [34],
#   [27],
#   [19, 15, 11, 10, 18],
#   [9, 45, 44, 49, 21, 24, 24, 25, 3, 20, 14, 5, 44, 25],
#   [29, 38, 35, 40, 7, 7, 7, 20, 44, 13, 19, 19, 47, 38, 32, 35],
#   [29, 33, 42, 2, 31, 21, 48, 15, 14, 30, 20, 6, 49, 21, 39],
#   [24, 8, 37, 44, 42, 1, 26, 32, 1, 11, 8, 45, 11, 49, 37, 2],
#   [14, 37, 10, 24, 48, 35, 15, 31, 36, 15, 1, 11, 34, 38, 33, 31, 27],
#   [17, 22, 25, 4, 2, 34, 12, 35, 20, 15, 45],
#   [47, 29, 2, 26, 17, 44, 24, 34, 1, 36, 41, 27, 41, 31, 24, 46, 47, 20, 37],
#   [42, 21, 1, 29, 41, 33, 16, 20, 6, 8],
#   [32, 33, 31, 19, 44, 43, 29, 1, 11],
#   [9, 7, 10, 43, 25, 1, 49, 29, 22, 6, 35, 29, 43, 7, 32, 26],
#   [29, 29, 6, 39, 18, 31, 27, 36, 10, 26, 1, 45, 18, 33, 49, 18, 4, 25, 40],
#   [39, 37, 42, 33, 44, 11, 7, 5, 25, 25],
#   [12, 39, 17, 45, 35, 41, 9, 18, 25, 47, 40, 24, 46, 46, 44, 9, 1],
#   [49, 36, 36, 21, 35, 1, 21, 24, 11, 31],
#   [15, 33, 45, 13, 27, 13, 10, 25, 3, 14, 41, 48, 6, 36, 36, 40, 42],
#   [40, 28, 11, 15, 24, 42, 42, 13, 12],
#   [8, 16, 45, 5],
#   [35, 18, 13, 3, 24, 34, 45, 12],
#   [42, 7, 40, 35, 36],
#   [15, 49, 27, 1, 21, 44],
#   [38, 23, 28, 33, 41, 29, 16, 6, 7, 28, 23, 25, 3],
#   [8, 37],
#   [49, 21, 36, 21, 24, 47, 2],
#   [41, 40, 24, 45, 4, 2, 29, 43, 15, 35, 2, 40, 3, 17, 5, 4, 4, 27, 37],
#   [48, 26, 29, 34, 37, 45, 30, 20, 38, 18],
#   [21, 35, 33, 49, 25, 29, 34, 6, 33, 38, 25, 46, 44, 35, 8, 23],
#   [5, 6, 37, 6, 34, 12, 20, 33, 24, 1, 44, 37, 32, 37, 24, 23],
#   [32, 27],
#   [15, 3, 11, 33, 15, 38, 5, 11, 14, 30],
#   [49, 43],
#   [37, 10],
#   [11, 11, 35, 39, 46, 9, 45, 18, 2, 24, 19, 9],
#   [13, 48, 29, 29, 16, 49, 6],
#   [36, 6, 8, 21, 6, 15],
#   [42, 7, 29, 18, 3, 10, 35, 6],
#   [42, 5, 43, 25, 17, 46, 44, 47],
#   [3, 4, 46, 39, 1, 27, 48, 22, 41, 22, 17, 44, 32, 11, 40, 44],
#   [14, 2, 9, 36, 37, 32],
#   [16, 5, 46, 1, 8, 27, 44, 20, 21, 16, 44, 28, 9],
#   [21, 11, 2],
#   [34, 35, 44, 47, 42, 47, 39],
#   [18, 11, 19, 3, 4, 33],
#   [9, 5, 33, 43, 4, 36, 40, 17, 20, 20, 44, 33, 28, 29, 14, 1, 45, 47],
#   [9, 33, 29, 23, 42],
#   [19, 38, 24, 36, 3, 15, 15, 12],
#   [25, 44, 13, 3, 19, 23, 12, 3, 28, 8, 2, 14, 22, 18, 43, 8],
#   [6, 3, 17, 26, 16],
#   [16, 10],
#   [21, 47, 46, 30, 23],
#   [36, 44, 31, 42, 16, 49, 17, 47, 46, 19, 32, 5, 32, 10],
#   [4, 37, 45, 2, 28, 24, 16, 15, 49, 45, 22, 4, 21],
#   [5, 36, 36, 32, 49, 32, 43, 45, 28, 8, 41, 42, 38],
#   [12],
#   [18, 17, 3, 26, 36, 30, 3, 43, 2, 21],
#   [43, 27, 21, 37, 35, 21, 33, 1, 29],
#   [22, 18, 21, 1, 11, 38],
#   [32, 34, 24, 16, 28, 10, 18, 11, 44, 7, 16, 11, 18, 5],
#   [21, 28, 43],
#   [43, 41, 40, 44, 35, 9, 21, 15],
#   [6, 42, 20, 22, 20, 46],
#   [21, 37, 4],
#   [40],
#   [32, 33, 45, 39, 31, 48, 3, 10, 27, 42, 26, 26, 39, 10, 44, 31, 39],
#   [47],
#   [24, 2, 2, 37, 6, 35, 34, 48, 35, 15, 49, 11],
#   [38, 6, 32, 6, 29, 8, 35, 16, 2, 15],
#   [8, 37, 22, 22, 8, 46],
#   [21, 14, 47, 28, 15, 10, 15, 39, 7, 20, 45, 38, 9, 39, 19],
#   [37, 24, 4, 8, 2, 28, 3, 8, 17, 49, 39, 18, 34, 29, 25, 6, 15, 46],
#   [36, 6, 32, 7, 27, 28, 31, 40, 14, 33, 7],
#   [29, 43, 44, 1, 6, 34, 46, 12, 21, 36, 12, 10],
#   [39, 18, 13, 46, 13, 8, 12, 25, 20, 39, 5, 11, 23, 28, 14, 30, 38, 16, 40],
#   [34, 2, 25, 49, 7, 17],
#   [22, 10, 39],
#   [3, 47, 44],
#   [14],
#   [43, 43, 3, 33],
#   [18, 27, 2, 17, 21, 39, 44, 7, 21, 9, 12, 14, 43, 13, 43, 36],
#   [13, 49, 25, 26, 19, 44, 1, 8, 25, 37, 24, 20, 2],
#   [26, 47],
#   [3, 44, 8, 40, 20, 11, 17, 17, 25, 41],
#   [19, 28, 22, 48, 45, 44, 31, 12, 23, 13, 36, 32],
#   [7, 28, 32, 34, 27, 7, 24],
#   [16, 37, 19, 12, 8, 27, 16],
#   [47, 10, 3, 49, 9, 27, 4],
#   [10, 37, 39, 26, 16, 1, 1, 10, 15, 44, 33, 17, 9, 47, 3, 27, 21, 46, 27],
#   [41, 7, 3, 1, 24, 19, 44, 30, 3, 47, 31, 13, 38, 25, 33, 17, 34, 19, 44],
#   [10, 33, 23, 23, 2, 2, 13, 36, 42, 14, 34, 21, 26, 21, 30, 33, 1, 48, 9],
#   [33, 28, 8, 46, 15, 13, 13, 2, 28, 39, 47, 41, 16, 16, 23, 30, 34, 26],
#   [36, 15, 9, 21, 32, 18, 32, 33, 2, 31, 38, 7, 21, 39, 7],
#   [3, 22, 29, 34, 12, 22, 26, 15, 48, 15, 38, 19, 10, 49, 46, 5, 36, 44],
#   [32, 17, 19, 9, 38],
#   [47, 30, 49, 30, 1, 36, 47, 23, 49, 49, 11, 22, 39, 37, 31, 4],
#   [32, 48, 48, 41, 23, 14, 43, 7, 19, 11, 30, 20, 10, 7, 8, 5, 34, 45, 16],
#   [1, 34, 15],
#   [5, 22, 13, 9, 27, 19, 46, 48],
#   [49, 27, 37, 36, 16, 14, 9, 37, 29, 45, 24, 10, 48, 27, 16, 40, 19, 42, 25],
#   [36, 36, 22, 13, 45, 36, 2, 49, 6, 13, 9],
#   [40, 30, 4, 3, 21, 12, 1, 13, 6, 33, 5, 19, 48, 22, 43, 3, 33, 45],
#   [31, 3, 37, 45, 23, 22],
#   [34, 7, 17, 29, 47, 25, 43, 10, 33, 14, 38, 21],
#   [26, 4, 10, 22, 35, 39],
#   [12, 1],
#   [32, 32, 45, 34, 43, 3, 15, 38, 20, 39, 48, 28, 41, 3, 5],
#   [45, 12, 37, 16, 10],
#   [9, 13, 42, 10, 37, 34, 5, 24, 4, 36],
#   [10, 29, 24, 47, 36, 42, 19, 17, 6, 28],
#   [34, 15, 11, 19, 14, 3, 23, 37, 5, 7, 19, 7, 28, 13, 37],
#   [28, 41],
#   [46, 27, 25, 39, 3, 42, 40, 21, 38, 30, 26],
#   [8, 18, 23, 43, 24, 29, 38, 1, 18, 2, 24, 35, 27, 35, 26],
#   [20, 40, 34, 39, 17, 5, 12, 30],
#   [28, 20, 10, 7, 5, 25, 42, 29, 32, 38, 36, 10, 41, 14, 15],
#   [32, 42, 19, 43, 8, 11, 11, 32, 47, 39, 33, 31, 29, 9, 49, 44, 46, 21, 28],
#   [27, 35, 32, 46, 19, 23, 20, 28, 19, 4, 48, 43, 13, 12, 45, 12, 41],
#   [45, 14, 17, 31, 13, 9, 37, 5, 13, 37],
#   [9, 28, 4, 7, 15, 30, 36, 21, 10, 43, 15],
#   [12, 34, 13, 31, 1, 7],
#   [42, 41, 27],
#   [27, 7],
#   [23, 7, 33, 5, 41, 23, 13, 24, 4, 39, 18, 26, 43, 14, 14],
#   [10, 14, 23, 21, 21, 18, 37, 21, 30, 13, 9, 44, 19, 26, 30],
#   [7, 46, 7, 32, 11, 45, 8, 48, 40, 11, 38, 49, 14, 18, 49],
#   [32, 44, 18],
#   [27, 44, 33, 6, 35, 39],
#   [2, 19, 1, 4, 37, 12, 21, 18],
#   [22, 33, 34, 41, 31, 42, 37],
#   [22, 37, 30, 16, 36, 45, 22, 22, 38, 9, 38, 11],
#   [4, 28, 46, 38],
#   [3, 8, 34, 4, 16, 49, 18, 19],
#   [21, 2, 31, 44, 21, 47, 23],
#   [26, 40, 22, 11, 37, 5, 49, 47, 37, 21, 17, 41, 1, 28, 26, 6, 31],
#   [25, 14, 18, 39, 18, 22, 3, 23, 4, 36, 9, 33, 44, 10, 46, 26, 43],
#   [32, 24, 32, 5],
#   [16, 40, 22, 45, 27, 32, 28, 16, 17, 27, 45, 26, 10, 24, 41, 28, 4],
#   [3, 11, 8, 22, 34, 4, 41, 17, 29, 49, 46, 48, 15],
#   [42],
#   [45, 26, 22, 21, 33, 14, 3, 47, 23, 49, 19, 14, 28, 45, 30, 29, 33, 46],
#   [14, 28, 15, 22, 15, 22, 48, 26, 24, 19, 43, 45],
#   [1, 35, 26, 18, 2, 21, 28, 19, 1, 28, 42, 42, 19, 41, 45, 6],
#   [4, 16, 39, 4, 44, 35, 47, 31, 29, 19, 11, 16],
#   [23, 12, 44, 16, 39, 1, 2, 12, 24, 40, 1, 3, 1, 27, 17],
#   [19],
#   [43, 7, 11, 25, 38, 30, 45, 31],
#   [32, 1, 28, 14, 33, 41],
#   [2, 41, 34, 48, 35, 12, 20, 2, 4],
#   [28, 46, 42, 15, 21],
#   [31, 7, 44, 9, 48, 37, 43, 26, 47, 6, 20, 9, 32, 5],
#   [26, 13, 12, 30, 24],
#   [25, 22, 47, 22, 25, 21, 26, 44, 24, 17, 5],
#   [13, 41, 37, 8, 17, 28, 3, 21, 32, 17, 36, 44, 38, 47, 28]])

# %% [markdown]
# ### output to csv file.

# %%
import csv
with open('marketbask1.csv','w') as csvfile:
    fwriter = csv.writer(csvfile, delimiter=',')
    for i in range(len(marketbasket)):
        fwriter.writerow(marketbasket[i])
csvfile.close()

# %%
key = 47
count = 0
for transaction in marketbasket:
    for x in transaction:
        if x == key: 
            count += 1

print key, count
# Out:
# 47 187
