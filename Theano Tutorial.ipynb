# %% [markdown]
# # Theano Tutorial
# (taken from http://nbviewer.ipython.org/github/craffel/theano-tutorial/blob/master/Theano%20Tutorial.ipynb)
#
# Theano is a software package which allows you to write symbolic code and compile it onto different architectures (in particular, CPU and GPU). It was developed by machine learning researchers at the University of Montreal. Its use is not limited to machine learning applications, but it was designed with machine learning in mind. It's especially good for machine learning techniques which are CPU-intensive and benefit from parallelization (e.g. large neural networks).
#
# This tutorial will cover the basic principles of Theano, including some common mental blocks which come up. It will also cover a simple multi-layer perceptron example. A more thorough Theano tutorial can be found here: http://deeplearning.net/software/theano/tutorial/
#
# Any comments or suggestions should be directed to me or feel free to submit a pull request.

# %%
# %matplotlib inline

# %%
import numpy as np
import matplotlib.pyplot as plt
import theano
# by convention, the tensor submodule is loaded as T
import theano.tensor as T

# %% [markdown]
# ## Basics
# ### Symbolic variables
# In Theano, all algorithms are defined symbolically. It is more like writing out math than writing code. The following Theano variables are symbolic; they don't have an explicit value.

# %%
# The theano.tensor submodule has various primitive symbolic variable types.
# Here, we're defining a scalar (0-d) variable.
# The argument gives the variable its name.
foo = T.scalar('foo')
# Now, we can define another variable bar which is just foo squared.
bar = foo**2
# It will also be a theano variable.
print type(bar)
print bar.type
# Using theano's pp (pretty print) function, we see that 
# bar is defined symbolically as the square of foo
print theano.pp(bar)

# %% [markdown]
# ### Functions
# To acutally compute things with Theano, you define symbolic functions, which can then be called with actual values to retrieve an actual value.

# %%
# We can't compute anything with foo and bar yet.
# We need to define a theano function first.
# The first argument of theano.function defines the inputs to the function.
# Note that bar relies on foo, so foo is an input to this function.
# theano.function will compile code for computing values of bar given values of foo
f = theano.function([foo], bar)
print f(3)

# %%
# Alternatively, in some cases you can use a symbolic variable's eval method.
# This can be more convenient than defining a function.
# The eval method takes a dictionary where the keys are theano variables and the values are values for those variables.
print bar.eval({foo: 3})

# %%
# We can also use Python functions to construct Theano variables.
# It seems pedantic here, but can make syntax cleaner for more complicated examples.
def square(x):
    return x**2
bar = square(foo)
print bar.eval({foo: 3})

# %% [markdown]
# #### theano.tensor
# Theano also has variable types for vectors, matricies, and tensors.
# The `theano.tensor` submodule has various functions for performing operations on these variables.

# %%
A = T.matrix('A')
x = T.vector('x')
b = T.vector('b')
y = T.dot(A, x) + b
# Note that squaring a matrix is element-wise
z = T.sum(A**2)

# %%
print theano.pp(z)
# Out:
# Sum((A ** TensorConstant{2}))

# %%
linear_mix = theano.function([A, x, theano.Param(b, default=np.array([0, 0]))], [y, z])
# We'll cover theano.config.floatX later
print linear_mix(np.array([[1, 2, 3],
                           [4, 5, 6]], dtype=theano.config.floatX), #A
                 np.array([1, 2, 3], dtype=theano.config.floatX), #x
                 np.array([4, 5], dtype=theano.config.floatX)) #b
# Out:
# ===============================
# ===============================
# /usr/bin/ld: cannot find -latlas
# collect2: ld returned 1 exit status
# 00001	#include <Python.h>
# 00002	#include <iostream>
# 00003	#include <math.h>
# 00004	#include <numpy/arrayobject.h>
# 00005	#include <numpy/arrayscalars.h>
# 00006	//////////////////////
# 00007	////  Support Code
# 00008	//////////////////////
# 00009
# 00010
# 00011	    extern "C"
# 00012	    {
# 00013
# 00014	        void xerbla_(char*, void *);
# 00015
# 00016	    /***********/
# 00017	    /* Level 1 */
# 00018	    /***********/
# 00019
# 00020	    /* Single Precision */
# 00021
# 00022	        void srot_(const int*, float *, const int*, float *, const int*, const float *, const float *);
# 00023	        void srotg_(float *,float *,float *,float *);
# 00024	        void srotm_( const int*, float *, const int*, float *, const int*, const float *);
# 00025	        void srotmg_(float *,float *,float *,const float *, float *);
# 00026	        void sswap_( const int*, float *, const int*, float *, const int*);
# 00027	        void scopy_( const int*, const float *, const int*, float *, const int*);
# 00028	        void saxpy_( const int*, const float *, const float *, const int*, float *, const int*);
# 00029	        float sdot_(const int*, const float *, const int*, const float *, const int*);
# 00030	        void sdot_sub_(const int*, const float *, const int*, const float *, const int*, float *);
# 00031	        void sdsdot_sub_( const int*, const float *, const float *, const int*, const float *, const int*, float *);
# 00032	        void sscal_( const int*, const float *, float *, const int*);
# 00033	        void snrm2_sub_( const int*, const float *, const int*, float *);
# 00034	        void sasum_sub_( const int*, const float *, const int*, float *);
# 00035	        void isamax_sub_( const int*, const float * , const int*, const int*);
# 00036
# 00037	    /* Double Precision */
# 00038
# 00039	        void drot_(const int*, double *, const int*, double *, const int*, const double *, const double *);
# 00040	        void drotg_(double *,double *,double *,double *);
# 00041	        void drotm_( const int*, double *, const int*, double *, const int*, const double *);
# 00042	        void drotmg_(double *,double *,double *,const double *, double *);
# 00043	        void dswap_( const int*, double *, const int*, double *, const int*);
# 00044	        void dcopy_( const int*, const double *, const int*, double *, const int*);
# 00045	        void daxpy_( const int*, const double *, const double *, const int*, double *, const int*);
# 00046	        void dswap_( const int*, double *, const int*, double *, const int*);
# 00047	        double ddot_(const int*, const double *, const int*, const double *, const int*);
# 00048	        void dsdot_sub_(const int*, const float *, const int*, const float *, const int*, double *);
# 00049	        void ddot_sub_( const int*, const double *, const int*, const double *, const int*, double *);
# 00050	        void dscal_( const int*, const double *, double *, const int*);
# 00051	        void dnrm2_sub_( const int*, const double *, const int*, double *);
# 00052	        void dasum_sub_( const int*, const double *, const int*, double *);
# 00053	        void idamax_sub_( const int*, const double * , const int*, const int*);
# 00054
# 00055	    /* Single Complex Precision */
# 00056
# 00057	        void cswap_( const int*, void *, const int*, void *, const int*);
# 00058	        void ccopy_( const int*, const void *, const int*, void *, const int*);
# 00059	        void caxpy_( const int*, const void *, const void *, const int*, void *, const int*);
# 00060	        void cswap_( const int*, void *, const int*, void *, const int*);
# 00061	        void cdotc_sub_( const int*, const void *, const int*, const void *, const int*, void *);
# 00062	        void cdotu_sub_( const int*, const void *, const int*, const void *, const int*, void *);
# 00063	        void cscal_( const int*, const void *, void *, const int*);
# 00064	        void icamax_sub_( const int*, const void *, const int*, const int*);
# 00065	        void csscal_( const int*, const float *, void *, const int*);
# 00066	        void scnrm2_sub_( const int*, const void *, const int*, float *);
# 00067	        void scasum_sub_( const int*, const void *, const int*, float *);
# 00068
# 00069	    /* Double Complex Precision */
# 00070
# 00071	        void zswap_( const int*, void *, const int*, void *, const int*);
# 00072	        void zcopy_( const int*, const void *, const int*, void *, const int*);
# 00073	        void zaxpy_( const int*, const void *, const void *, const int*, void *, const int*);
# 00074	        void zswap_( const int*, void *, const int*, void *, const int*);
# 00075	        void zdotc_sub_( const int*, const void *, const int*, const void *, const int*, void *);
# 00076	        void zdotu_sub_( const int*, const void *, const int*, const void *, const int*, void *);
# 00077	        void zdscal_( const int*, const double *, void *, const int*);
# 00078	        void zscal_( const int*, const void *, void *, const int*);
# 00079	        void dznrm2_sub_( const int*, const void *, const int*, double *);
# 00080	        void dzasum_sub_( const int*, const void *, const int*, double *);
# 00081	        void izamax_sub_( const int*, const void *, const int*, const int*);
# 00082
# 00083	    /***********/
# 00084	    /* Level 2 */
# 00085	    /***********/
# 00086
# 00087	    /* Single Precision */
# 00088
# 00089	        void sgemv_(char*, const int*, const int*, const float *, const float *, const int*, const float *, const int*, const float *, float *, const int*);
# 00090	        void sgbmv_(char*, const int*, const int*, const int*, const int*, const float *,  const float *, const int*, const float *, const int*, const float *, float *, const int*);
# 00091	        void ssymv_(char*, const int*, const float *, const float *, const int*, const float *,  const int*, const float *, float *, const int*);
# 00092	        void ssbmv_(char*, const int*, const int*, const float *, const float *, const int*, const float *, const int*, const float *, float *, const int*);
# 00093	        void sspmv_(char*, const int*, const float *, const float *, const float *, const int*, const float *, float *, const int*);
# 00094	        void strmv_( char*, char*, char*, const int*, const float *, const int*, float *, const int*);
# 00095	        void stbmv_( char*, char*, char*, const int*, const int*, const float *, const int*, float *, const int*);
# 00096	        void strsv_( char*, char*, char*, const int*, const float *, const int*, float *, const int*);
# 00097	        void stbsv_( char*, char*, char*, const int*, const int*, const float *, const int*, float *, const int*);
# 00098	        void stpmv_( char*, char*, char*, const int*, const float *, float *, const int*);
# 00099	        void stpsv_( char*, char*, char*, const int*, const float *, float *, const int*);
# 00100	        void sger_( const int*, const int*, const float *, const float *, const int*, const float *, const int*, float *, const int*);
# 00101	        void ssyr_(char*, const int*, const float *, const float *, const int*, float *, const int*);
# 00102	        void sspr_(char*, const int*, const float *, const float *, const int*, float *);
# 00103	        void sspr2_(char*, const int*, const float *, const float *, const int*, const float *, const int*,  float *);
# 00104	        void ssyr2_(char*, const int*, const float *, const float *, const int*, const float *, const int*,  float *, const int*);
# 00105
# 00106	    /* Double Precision */
# 00107
# 00108	        void dgemv_(char*, const int*, const int*, const double *, const double *, const int*, const double *, const int*, const double *, double *, const int*);
# 00109	        void dgbmv_(char*, const int*, const int*, const int*, const int*, const double *,  const double *, const int*, const double *, const int*, const double *, double *, const int*);
# 00110	        void dsymv_(char*, const int*, const double *, const double *, const int*, const double *,  const int*, const double *, double *, const int*);
# 00111	        void dsbmv_(char*, const int*, const int*, const double *, const double *, const int*, const double *, const int*, const double *, double *, const int*);
# 00112	        void dspmv_(char*, const int*, const double *, const double *, const double *, const int*, const double *, double *, const int*);
# 00113	        void dtrmv_( char*, char*, char*, const int*, const double *, const int*, double *, const int*);
# 00114	        void dtbmv_( char*, char*, char*, const int*, const int*, const double *, const int*, double *, const int*);
# 00115	        void dtrsv_( char*, char*, char*, const int*, const double *, const int*, double *, const int*);
# 00116	        void dtbsv_( char*, char*, char*, const int*, const int*, const double *, const int*, double *, const int*);
# 00117	        void dtpmv_( char*, char*, char*, const int*, const double *, double *, const int*);
# 00118	        void dtpsv_( char*, char*, char*, const int*, const double *, double *, const int*);
# 00119	        void dger_( const int*, const int*, const double *, const double *, const int*, const double *, const int*, double *, const int*);
# 00120	        void dsyr_(char*, const int*, const double *, const double *, const int*, double *, const int*);
# 00121	        void dspr_(char*, const int*, const double *, const double *, const int*, double *);
# 00122	        void dspr2_(char*, const int*, const double *, const double *, const int*, const double *, const int*,  double *);
# 00123	        void dsyr2_(char*, const int*, const double *, const double *, const int*, const double *, const int*,  double *, const int*);
# 00124
# 00125	    /* Single Complex Precision */
# 00126
# 00127	        void cgemv_(char*, const int*, const int*, const void *, const void *, const int*, const void *, const int*, const void *, void *, const int*);
# 00128	        void cgbmv_(char*, const int*, const int*, const int*, const int*, const void *,  const void *, const int*, const void *, const int*, const void *, void *, const int*);
# 00129	        void chemv_(char*, const int*, const void *, const void *, const int*, const void *, const int*, const void *, void *, const int*);
# 00130	        void chbmv_(char*, const int*, const int*, const void *, const void *, const int*, const void *, const int*, const void *, void *, const int*);
# 00131	        void chpmv_(char*, const int*, const void *, const void *, const void *, const int*, const void *, void *, const int*);
# 00132	        void ctrmv_( char*, char*, char*, const int*, const void *, const int*, void *, const int*);
# 00133	        void ctbmv_( char*, char*, char*, const int*, const int*, const void *, const int*, void *, const int*);
# 00134	        void ctpmv_( char*, char*, char*, const int*, const void *, void *, const int*);
# 00135	        void ctrsv_( char*, char*, char*, const int*, const void *, const int*, void *, const int*);
# 00136	        void ctbsv_( char*, char*, char*, const int*, const int*, const void *, const int*, void *, const int*);
# 00137	        void ctpsv_( char*, char*, char*, const int*, const void *, void *,const int*);
# 00138	        void cgerc_( const int*, const int*, const void *, const void *, const int*, const void *, const int*, void *, const int*);
# 00139	        void cgeru_( const int*, const int*, const void *, const void *, const int*, const void *, const int*, void *,  const int*);
# 00140	        void cher_(char*, const int*, const float *, const void *, const int*, void *, const int*);
# 00141	        void cher2_(char*, const int*, const void *, const void *, const int*, const void *, const int*, void *, const int*);
# 00142	        void chpr_(char*, const int*, const float *, const void *, const int*, void *);
# 00143	        void chpr2_(char*, const int*, const float *, const void *, const int*, const void *, const int*, void *);
# 00144
# 00145	    /* Double Complex Precision */
# 00146
# 00147	        void zgemv_(char*, const int*, const int*, const void *, const void *, const int*, const void *, const int*, const void *, void *, const int*);
# 00148	        void zgbmv_(char*, const int*, const int*, const int*, const int*, const void *,  const void *, const int*, const void *, const int*, const void *, void *, const int*);
# 00149	        void zhemv_(char*, const int*, const void *, const void *, const int*, const void *, const int*, const void *, void *, const int*);
# 00150	        void zhbmv_(char*, const int*, const int*, const void *, const void *, const int*, const void *, const int*, const void *, void *, const int*);
# 00151	        void zhpmv_(char*, const int*, const void *, const void *, const void *, const int*, const void *, void *, const int*);
# 00152	        void ztrmv_( char*, char*, char*, const int*, const void *, const int*, void *, const int*);
# 00153	        void ztbmv_( char*, char*, char*, const int*, const int*, const void *, const int*, void *, const int*);
# 00154	        void ztpmv_( char*, char*, char*, const int*, const void *, void *, const int*);
# 00155	        void ztrsv_( char*, char*, char*, const int*, const void *, const int*, void *, const int*);
# 00156	        void ztbsv_( char*, char*, char*, const int*, const int*, const void *, const int*, void *, const int*);
# 00157	        void ztpsv_( char*, char*, char*, const int*, const void *, void *,const int*);
# 00158	        void zgerc_( const int*, const int*, const void *, const void *, const int*, const void *, const int*, void *, const int*);
# 00159	        void zgeru_( const int*, const int*, const void *, const void *, const int*, const void *, const int*, void *,  const int*);
# 00160	        void zher_(char*, const int*, const double *, const void *, const int*, void *, const int*);
# 00161	        void zher2_(char*, const int*, const void *, const void *, const int*, const void *, const int*, void *, const int*);
# 00162	        void zhpr_(char*, const int*, const double *, const void *, const int*, void *);
# 00163	        void zhpr2_(char*, const int*, const double *, const void *, const int*, const void *, const int*, void *);
# 00164
# 00165	    /***********/
# 00166	    /* Level 3 */
# 00167	    /***********/
# 00168
# 00169	    /* Single Precision */
# 00170
# 00171	        void sgemm_(char*, char*, const int*, const int*, const int*, const float *, const float *, const int*, const float *, const int*, const float *, float *, const int*);
# 00172	        void ssymm_(char*, char*, const int*, const int*, const float *, const float *, const int*, const float *, const int*, const float *, float *, const int*);
# 00173	        void ssyrk_(char*, char*, const int*, const int*, const float *, const float *, const int*, const float *, float *, const int*);
# 00174	        void ssyr2k_(char*, char*, const int*, const int*, const float *, const float *, const int*, const float *, const int*, const float *, float *, const int*);
# 00175	        void strmm_(char*, char*, char*, char*, const int*, const int*, const float *, const float *, const int*, float *, const int*);
# 00176	        void strsm_(char*, char*, char*, char*, const int*, const int*, const float *, const float *, const int*, float *, const int*);
# 00177
# 00178	    /* Double Precision */
# 00179
# 00180	        void dgemm_(char*, char*, const int*, const int*, const int*, const double *, const double *, const int*, const double *, const int*, const double *, double *, const int*);
# 00181	        void dsymm_(char*, char*, const int*, const int*, const double *, const double *, const int*, const double *, const int*, const double *, double *, const int*);
# 00182	        void dsyrk_(char*, char*, const int*, const int*, const double *, const double *, const int*, const double *, double *, const int*);
# 00183	        void dsyr2k_(char*, char*, const int*, const int*, const double *, const double *, const int*, const double *, const int*, const double *, double *, const int*);
# 00184	        void dtrmm_(char*, char*, char*, char*, const int*, const int*, const double *, const double *, const int*, double *, const int*);
# 00185	        void dtrsm_(char*, char*, char*, char*, const int*, const int*, const double *, const double *, const int*, double *, const int*);
# 00186
# 00187	    /* Single Complex Precision */
# 00188
# 00189	        void cgemm_(char*, char*, const int*, const int*, const int*, const float *, const float *, const int*, const float *, const int*, const float *, float *, const int*);
# 00190	        void csymm_(char*, char*, const int*, const int*, const float *, const float *, const int*, const float *, const int*, const float *, float *, const int*);
# 00191	        void chemm_(char*, char*, const int*, const int*, const float *, const float *, const int*, const float *, const int*, const float *, float *, const int*);
# 00192	        void csyrk_(char*, char*, const int*, const int*, const float *, const float *, const int*, const float *, float *, const int*);
# 00193	        void cherk_(char*, char*, const int*, const int*, const float *, const float *, const int*, const float *, float *, const int*);
# 00194	        void csyr2k_(char*, char*, const int*, const int*, const float *, const float *, const int*, const float *, const int*, const float *, float *, const int*);
# 00195	        void cher2k_(char*, char*, const int*, const int*, const float *, const float *, const int*, const float *, const int*, const float *, float *, const int*);
# 00196	        void ctrmm_(char*, char*, char*, char*, const int*, const int*, const float *, const float *, const int*, float *, const int*);
# 00197	        void ctrsm_(char*, char*, char*, char*, const int*, const int*, const float *, const float *, const int*, float *, const int*);
# 00198
# 00199	    /* Double Complex Precision */
# 00200
# 00201	        void zgemm_(char*, char*, const int*, const int*, const int*, const double *, const double *, const int*, const double *, const int*, const double *, double *, const int*);
# 00202	        void zsymm_(char*, char*, const int*, const int*, const double *, const double *, const int*, const double *, const int*, const double *, double *, const int*);
# 00203	        void zhemm_(char*, char*, const int*, const int*, const double *, const double *, const int*, const double *, const int*, const double *, double *, const int*);
# 00204	        void zsyrk_(char*, char*, const int*, const int*, const double *, const double *, const int*, const double *, double *, const int*);
# 00205	        void zherk_(char*, char*, const int*, const int*, const double *, const double *, const int*, const double *, double *, const int*);
# 00206	        void zsyr2k_(char*, char*, const int*, const int*, const double *, const double *, const int*, const double *, const int*, const double *, double *, const int*);
# 00207	        void zher2k_(char*, char*, const int*, const int*, const double *, const double *, const int*, const double *, const int*, const double *, double *, const int*);
# 00208	        void ztrmm_(char*, char*, char*, char*, const int*, const int*, const double *, const double *, const int*, double *, const int*);
# 00209	        void ztrsm_(char*, char*, char*, char*, const int*, const int*, const double *, const double *, const int*, double *, const int*);
# 00210
# 00211	    }
# 00212
# 00213
# 00214	    struct __struct_compiled_op_c9411e9ce176ac05f48860cfa5375e97 {
# 00215	        PyObject* __ERROR;
# 00216
# 00217	        PyObject* storage_V3;
# 00218	PyObject* storage_V5;
# 00219	PyObject* storage_V7;
# 00220	PyObject* storage_V9;
# 00221	PyObject* storage_V1;
# 00222
# 00223
# 00224	        __struct_compiled_op_c9411e9ce176ac05f48860cfa5375e97() {}
# 00225	        ~__struct_compiled_op_c9411e9ce176ac05f48860cfa5375e97(void) {
# 00226	            cleanup();
# 00227	        }
# 00228
# 00229	        int init(PyObject* __ERROR, PyObject* storage_V3, PyObject* storage_V5, PyObject* storage_V7, PyObject* storage_V9, PyObject* storage_V1) {
# 00230	            Py_XINCREF(storage_V3);
# 00231	Py_XINCREF(storage_V5);
# 00232	Py_XINCREF(storage_V7);
# 00233	Py_XINCREF(storage_V9);
# 00234	Py_XINCREF(storage_V1);
# 00235	            this->storage_V3 = storage_V3;
# 00236	this->storage_V5 = storage_V5;
# 00237	this->storage_V7 = storage_V7;
# 00238	this->storage_V9 = storage_V9;
# 00239	this->storage_V1 = storage_V1;
# 00240	            int __failure = 0;
# 00241
# 00242	{
# 00243
# 00244	{
# 00245
# 00246	{
# 00247
# 00248	{
# 00249
# 00250	{
# 00251
# 00252	            this->__ERROR = __ERROR;
# 00253	            return 0;
# 00254	            __label_9:
# 00255
# 00256	double __DUMMY_9;
# 00257
# 00258	}
# 00259	__label_7:
# 00260
# 00261	double __DUMMY_7;
# 00262
# 00263	}
# 00264	__label_5:
# 00265
# 00266	double __DUMMY_5;
# 00267
# 00268	}
# 00269	__label_3:
# 00270
# 00271	double __DUMMY_3;
# 00272
# 00273	}
# 00274	__label_1:
# 00275
# 00276	double __DUMMY_1;
# 00277
# 00278	}
# 00279
# 00280	            Py_XDECREF(this->storage_V3);
# 00281	Py_XDECREF(this->storage_V5);
# 00282	Py_XDECREF(this->storage_V7);
# 00283	Py_XDECREF(this->storage_V9);
# 00284	Py_XDECREF(this->storage_V1);
# 00285
# 00286	        if (__failure) {
# 00287	            // When there is a failure, this code puts the exception
# 00288	            // in __ERROR.
# 00289	            PyObject* err_type = NULL;
# 00290	            PyObject* err_msg = NULL;
# 00291	            PyObject* err_traceback = NULL;
# 00292	            PyErr_Fetch(&err_type, &err_msg, &err_traceback);
# 00293	            if (!err_type) {err_type = Py_None;Py_INCREF(Py_None);}
# 00294	            if (!err_msg) {err_msg = Py_None; Py_INCREF(Py_None);}
# 00295	            if (!err_traceback) {err_traceback = Py_None; Py_INCREF(Py_None);}
# 00296	            PyObject* old_err_type = PyList_GET_ITEM(__ERROR, 0);
# 00297	            PyObject* old_err_msg = PyList_GET_ITEM(__ERROR, 1);
# 00298	            PyObject* old_err_traceback = PyList_GET_ITEM(__ERROR, 2);
# 00299	            PyList_SET_ITEM(__ERROR, 0, err_type);
# 00300	            PyList_SET_ITEM(__ERROR, 1, err_msg);
# 00301	            PyList_SET_ITEM(__ERROR, 2, err_traceback);
# 00302	            {Py_XDECREF(old_err_type);}
# 00303	            {Py_XDECREF(old_err_msg);}
# 00304	            {Py_XDECREF(old_err_traceback);}
# 00305	        }
# 00306	        // The failure code is returned to index what code block failed.
# 00307	        return __failure;
# 00308
# 00309	        }
# 00310	        void cleanup(void) {
# 00311	            __label_1:
# 00312
# 00313	double __DUMMY_1;
# 00314	__label_3:
# 00315
# 00316	double __DUMMY_3;
# 00317	__label_5:
# 00318
# 00319	double __DUMMY_5;
# 00320	__label_7:
# 00321
# 00322	double __DUMMY_7;
# 00323	__label_9:
# 00324
# 00325	double __DUMMY_9;
# 00326
# 00327	            Py_XDECREF(this->storage_V3);
# 00328	Py_XDECREF(this->storage_V5);
# 00329	Py_XDECREF(this->storage_V7);
# 00330	Py_XDECREF(this->storage_V9);
# 00331	Py_XDECREF(this->storage_V1);
# 00332	        }
# 00333	        int run(void) {
# 00334	            int __failure = 0;
# 00335
# 00336	    PyObject* py_V1;
# 00337
# 00338	        PyArrayObject* V1;
# 00339	        int type_num_V1;
# 00340	        typedef npy_float64 dtype_V1;
# 00341
# 00342	    PyObject* py_V3;
# 00343
# 00344	        PyArrayObject* V3;
# 00345	        int type_num_V3;
# 00346	        typedef npy_float64 dtype_V3;
# 00347
# 00348	    PyObject* py_V5;
# 00349
# 00350	        PyArrayObject* V5;
# 00351	        int type_num_V5;
# 00352	        typedef npy_float64 dtype_V5;
# 00353
# 00354	    PyObject* py_V7;
# 00355
# 00356	        PyArrayObject* V7;
# 00357	        int type_num_V7;
# 00358	        typedef npy_float64 dtype_V7;
# 00359
# 00360	    PyObject* py_V9;
# 00361
# 00362	        PyArrayObject* V9;
# 00363	        int type_num_V9;
# 00364	        typedef npy_float64 dtype_V9;
# 00365
# 00366	{
# 00367
# 00368	    py_V1 = Py_None;
# 00369	    {Py_XINCREF(py_V1);}
# 00370
# 00371	        V1 = NULL;
# 00372	        type_num_V1 = NPY_FLOAT64;
# 00373
# 00374	{
# 00375
# 00376	    py_V3 = PyList_GET_ITEM(storage_V3, 0);
# 00377	    {Py_XINCREF(py_V3);}
# 00378
# 00379	        V3 = NULL;
# 00380	        if (py_V3 == Py_None) {
# 00381	            // We can either fail here or set V3 to NULL and rely on Ops
# 00382	            // using tensors to handle the NULL case, but if they fail to do so
# 00383	            // they'll end up with nasty segfaults, so this is public service.
# 00384	            PyErr_SetString(PyExc_ValueError, "expected an ndarray, not None");
# 00385	            {
# 00386	        __failure = 4;
# 00387	        if (!PyErr_Occurred()) {
# 00388	            PyErr_SetString(PyExc_RuntimeError,
# 00389	                "Unexpected error in an Op's C code. "
# 00390	                "No Python exception was set.");
# 00391	            }
# 00392	        goto __label_4;}
# 00393	        }
# 00394	        if (!PyArray_Check(py_V3)) {
# 00395	            PyErr_SetString(PyExc_ValueError, "expected an ndarray");
# 00396	            {
# 00397	        __failure = 4;
# 00398	        if (!PyErr_Occurred()) {
# 00399	            PyErr_SetString(PyExc_RuntimeError,
# 00400	                "Unexpected error in an Op's C code. "
# 00401	                "No Python exception was set.");
# 00402	            }
# 00403	        goto __label_4;}
# 00404	        }
# 00405	        // We expect NPY_FLOAT64
# 00406	        type_num_V3 = PyArray_TYPE((PyArrayObject*) py_V3);
# 00407	        if (!PyArray_ISALIGNED((PyArrayObject*) py_V3)) {
# 00408	            PyArrayObject * tmp = (PyArrayObject*) py_V3;
# 00409	            PyErr_Format(PyExc_NotImplementedError,
# 00410	                         "expected an aligned array of type %ld "
# 00411	                         "(NPY_FLOAT64), got non-aligned array of type %ld"
# 00412	                         " with %ld dimensions, with 3 last dims "
# 00413	                         "%ld, %ld, %ld"
# 00414	                         " and 3 last strides %ld %ld, %ld.",
# 00415	                         (long int) NPY_FLOAT64,
# 00416	                         (long int) type_num_V3,
# 00417	                         (long int) PyArray_NDIM(tmp),
# 00418	                         (long int) PyArray_NDIM(tmp) >= 3 ?
# 00419	        PyArray_DIMS(tmp)[PyArray_NDIM(tmp)-3] : -1,
# 00420	                         (long int) PyArray_NDIM(tmp) >= 2 ?
# 00421	        PyArray_DIMS(tmp)[PyArray_NDIM(tmp)-2] : -1,
# 00422	                         (long int) PyArray_NDIM(tmp) >= 1 ?
# 00423	        PyArray_DIMS(tmp)[PyArray_NDIM(tmp)-1] : -1,
# 00424	                         (long int) PyArray_NDIM(tmp) >= 3 ?
# 00425	        PyArray_STRIDES(tmp)[PyArray_NDIM(tmp)-3] : -1,
# 00426	                         (long int) PyArray_NDIM(tmp) >= 2 ?
# 00427	        PyArray_STRIDES(tmp)[PyArray_NDIM(tmp)-2] : -1,
# 00428	                         (long int) PyArray_NDIM(tmp) >= 1 ?
# 00429	        PyArray_STRIDES(tmp)[PyArray_NDIM(tmp)-1] : -1
# 00430	        );
# 00431	            {
# 00432	        __failure = 4;
# 00433	        if (!PyErr_Occurred()) {
# 00434	            PyErr_SetString(PyExc_RuntimeError,
# 00435	                "Unexpected error in an Op's C code. "
# 00436	                "No Python exception was set.");
# 00437	            }
# 00438	        goto __label_4;}
# 00439	        }
# 00440	        // This is a TypeError to be consistent with DEBUG_MODE
# 00441	        // Note: DEBUG_MODE also tells the name of the container
# 00442	        if (type_num_V3 != NPY_FLOAT64) {
# 00443	            PyErr_Format(PyExc_TypeError,
# 00444	                         "expected type_num %d (NPY_FLOAT64) got %d",
# 00445	                         NPY_FLOAT64, type_num_V3);
# 00446	            {
# 00447	        __failure = 4;
# 00448	        if (!PyErr_Occurred()) {
# 00449	            PyErr_SetString(PyExc_RuntimeError,
# 00450	                "Unexpected error in an Op's C code. "
# 00451	                "No Python exception was set.");
# 00452	            }
# 00453	        goto __label_4;}
# 00454	        }
# 00455	        V3 = (PyArrayObject*)(py_V3);
# 00456	        Py_XINCREF(V3);
# 00457
# 00458	{
# 00459
# 00460	    py_V5 = PyList_GET_ITEM(storage_V5, 0);
# 00461	    {Py_XINCREF(py_V5);}
# 00462
# 00463	        V5 = NULL;
# 00464	        if (py_V5 == Py_None) {
# 00465	            // We can either fail here or set V5 to NULL and rely on Ops
# 00466	            // using tensors to handle the NULL case, but if they fail to do so
# 00467	            // they'll end up with nasty segfaults, so this is public service.
# 00468	            PyErr_SetString(PyExc_ValueError, "expected an ndarray, not None");
# 00469	            {
# 00470	        __failure = 6;
# 00471	        if (!PyErr_Occurred()) {
# 00472	            PyErr_SetString(PyExc_RuntimeError,
# 00473	                "Unexpected error in an Op's C code. "
# 00474	                "No Python exception was set.");
# 00475	            }
# 00476	        goto __label_6;}
# 00477	        }
# 00478	        if (!PyArray_Check(py_V5)) {
# 00479	            PyErr_SetString(PyExc_ValueError, "expected an ndarray");
# 00480	            {
# 00481	        __failure = 6;
# 00482	        if (!PyErr_Occurred()) {
# 00483	            PyErr_SetString(PyExc_RuntimeError,
# 00484	                "Unexpected error in an Op's C code. "
# 00485	                "No Python exception was set.");
# 00486	            }
# 00487	        goto __label_6;}
# 00488	        }
# 00489	        // We expect NPY_FLOAT64
# 00490	        type_num_V5 = PyArray_TYPE((PyArrayObject*) py_V5);
# 00491	        if (!PyArray_ISALIGNED((PyArrayObject*) py_V5)) {
# 00492	            PyArrayObject * tmp = (PyArrayObject*) py_V5;
# 00493	            PyErr_Format(PyExc_NotImplementedError,
# 00494	                         "expected an aligned array of type %ld "
# 00495	                         "(NPY_FLOAT64), got non-aligned array of type %ld"
# 00496	                         " with %ld dimensions, with 3 last dims "
# 00497	                         "%ld, %ld, %ld"
# 00498	                         " and 3 last strides %ld %ld, %ld.",
# 00499	                         (long int) NPY_FLOAT64,
# 00500	                         (long int) type_num_V5,
# 00501	                         (long int) PyArray_NDIM(tmp),
# 00502	                         (long int) PyArray_NDIM(tmp) >= 3 ?
# 00503	        PyArray_DIMS(tmp)[PyArray_NDIM(tmp)-3] : -1,
# 00504	                         (long int) PyArray_NDIM(tmp) >= 2 ?
# 00505	        PyArray_DIMS(tmp)[PyArray_NDIM(tmp)-2] : -1,
# 00506	                         (long int) PyArray_NDIM(tmp) >= 1 ?
# 00507	        PyArray_DIMS(tmp)[PyArray_NDIM(tmp)-1] : -1,
# 00508	                         (long int) PyArray_NDIM(tmp) >= 3 ?
# 00509	        PyArray_STRIDES(tmp)[PyArray_NDIM(tmp)-3] : -1,
# 00510	                         (long int) PyArray_NDIM(tmp) >= 2 ?
# 00511	        PyArray_STRIDES(tmp)[PyArray_NDIM(tmp)-2] : -1,
# 00512	                         (long int) PyArray_NDIM(tmp) >= 1 ?
# 00513	        PyArray_STRIDES(tmp)[PyArray_NDIM(tmp)-1] : -1
# 00514	        );
# 00515	            {
# 00516	        __failure = 6;
# 00517	        if (!PyErr_Occurred()) {
# 00518	            PyErr_SetString(PyExc_RuntimeError,
# 00519	                "Unexpected error in an Op's C code. "
# 00520	                "No Python exception was set.");
# 00521	            }
# 00522	        goto __label_6;}
# 00523	        }
# 00524	        // This is a TypeError to be consistent with DEBUG_MODE
# 00525	        // Note: DEBUG_MODE also tells the name of the container
# 00526	        if (type_num_V5 != NPY_FLOAT64) {
# 00527	            PyErr_Format(PyExc_TypeError,
# 00528	                         "expected type_num %d (NPY_FLOAT64) got %d",
# 00529	                         NPY_FLOAT64, type_num_V5);
# 00530	            {
# 00531	        __failure = 6;
# 00532	        if (!PyErr_Occurred()) {
# 00533	            PyErr_SetString(PyExc_RuntimeError,
# 00534	                "Unexpected error in an Op's C code. "
# 00535	                "No Python exception was set.");
# 00536	            }
# 00537	        goto __label_6;}
# 00538	        }
# 00539	        V5 = (PyArrayObject*)(py_V5);
# 00540	        Py_XINCREF(V5);
# 00541
# 00542	{
# 00543
# 00544	    py_V7 = PyList_GET_ITEM(storage_V7, 0);
# 00545	    {Py_XINCREF(py_V7);}
# 00546
# 00547	        V7 = NULL;
# 00548	        if (py_V7 == Py_None) {
# 00549	            // We can either fail here or set V7 to NULL and rely on Ops
# 00550	            // using tensors to handle the NULL case, but if they fail to do so
# 00551	            // they'll end up with nasty segfaults, so this is public service.
# 00552	            PyErr_SetString(PyExc_ValueError, "expected an ndarray, not None");
# 00553	            {
# 00554	        __failure = 8;
# 00555	        if (!PyErr_Occurred()) {
# 00556	            PyErr_SetString(PyExc_RuntimeError,
# 00557	                "Unexpected error in an Op's C code. "
# 00558	                "No Python exception was set.");
# 00559	            }
# 00560	        goto __label_8;}
# 00561	        }
# 00562	        if (!PyArray_Check(py_V7)) {
# 00563	            PyErr_SetString(PyExc_ValueError, "expected an ndarray");
# 00564	            {
# 00565	        __failure = 8;
# 00566	        if (!PyErr_Occurred()) {
# 00567	            PyErr_SetString(PyExc_RuntimeError,
# 00568	                "Unexpected error in an Op's C code. "
# 00569	                "No Python exception was set.");
# 00570	            }
# 00571	        goto __label_8;}
# 00572	        }
# 00573	        // We expect NPY_FLOAT64
# 00574	        type_num_V7 = PyArray_TYPE((PyArrayObject*) py_V7);
# 00575	        if (!PyArray_ISALIGNED((PyArrayObject*) py_V7)) {
# 00576	            PyArrayObject * tmp = (PyArrayObject*) py_V7;
# 00577	            PyErr_Format(PyExc_NotImplementedError,
# 00578	                         "expected an aligned array of type %ld "
# 00579	                         "(NPY_FLOAT64), got non-aligned array of type %ld"
# 00580	                         " with %ld dimensions, with 3 last dims "
# 00581	                         "%ld, %ld, %ld"
# 00582	                         " and 3 last strides %ld %ld, %ld.",
# 00583	                         (long int) NPY_FLOAT64,
# 00584	                         (long int) type_num_V7,
# 00585	                         (long int) PyArray_NDIM(tmp),
# 00586	                         (long int) PyArray_NDIM(tmp) >= 3 ?
# 00587	        PyArray_DIMS(tmp)[PyArray_NDIM(tmp)-3] : -1,
# 00588	                         (long int) PyArray_NDIM(tmp) >= 2 ?
# 00589	        PyArray_DIMS(tmp)[PyArray_NDIM(tmp)-2] : -1,
# 00590	                         (long int) PyArray_NDIM(tmp) >= 1 ?
# 00591	        PyArray_DIMS(tmp)[PyArray_NDIM(tmp)-1] : -1,
# 00592	                         (long int) PyArray_NDIM(tmp) >= 3 ?
# 00593	        PyArray_STRIDES(tmp)[PyArray_NDIM(tmp)-3] : -1,
# 00594	                         (long int) PyArray_NDIM(tmp) >= 2 ?
# 00595	        PyArray_STRIDES(tmp)[PyArray_NDIM(tmp)-2] : -1,
# 00596	                         (long int) PyArray_NDIM(tmp) >= 1 ?
# 00597	        PyArray_STRIDES(tmp)[PyArray_NDIM(tmp)-1] : -1
# 00598	        );
# 00599	            {
# 00600	        __failure = 8;
# 00601	        if (!PyErr_Occurred()) {
# 00602	            PyErr_SetString(PyExc_RuntimeError,
# 00603	                "Unexpected error in an Op's C code. "
# 00604	                "No Python exception was set.");
# 00605	            }
# 00606	        goto __label_8;}
# 00607	        }
# 00608	        // This is a TypeError to be consistent with DEBUG_MODE
# 00609	        // Note: DEBUG_MODE also tells the name of the container
# 00610	        if (type_num_V7 != NPY_FLOAT64) {
# 00611	            PyErr_Format(PyExc_TypeError,
# 00612	                         "expected type_num %d (NPY_FLOAT64) got %d",
# 00613	                         NPY_FLOAT64, type_num_V7);
# 00614	            {
# 00615	        __failure = 8;
# 00616	        if (!PyErr_Occurred()) {
# 00617	            PyErr_SetString(PyExc_RuntimeError,
# 00618	                "Unexpected error in an Op's C code. "
# 00619	                "No Python exception was set.");
# 00620	            }
# 00621	        goto __label_8;}
# 00622	        }
# 00623	        V7 = (PyArrayObject*)(py_V7);
# 00624	        Py_XINCREF(V7);
# 00625
# 00626	{
# 00627
# 00628	    py_V9 = PyList_GET_ITEM(storage_V9, 0);
# 00629	    {Py_XINCREF(py_V9);}
# 00630
# 00631	        V9 = NULL;
# 00632	        if (py_V9 == Py_None) {
# 00633	            // We can either fail here or set V9 to NULL and rely on Ops
# 00634	            // using tensors to handle the NULL case, but if they fail to do so
# 00635	            // they'll end up with nasty segfaults, so this is public service.
# 00636	            PyErr_SetString(PyExc_ValueError, "expected an ndarray, not None");
# 00637	            {
# 00638	        __failure = 10;
# 00639	        if (!PyErr_Occurred()) {
# 00640	            PyErr_SetString(PyExc_RuntimeError,
# 00641	                "Unexpected error in an Op's C code. "
# 00642	                "No Python exception was set.");
# 00643	            }
# 00644	        goto __label_10;}
# 00645	        }
# 00646	        if (!PyArray_Check(py_V9)) {
# 00647	            PyErr_SetString(PyExc_ValueError, "expected an ndarray");
# 00648	            {
# 00649	        __failure = 10;
# 00650	        if (!PyErr_Occurred()) {
# 00651	            PyErr_SetString(PyExc_RuntimeError,
# 00652	                "Unexpected error in an Op's C code. "
# 00653	                "No Python exception was set.");
# 00654	            }
# 00655	        goto __label_10;}
# 00656	        }
# 00657	        // We expect NPY_FLOAT64
# 00658	        type_num_V9 = PyArray_TYPE((PyArrayObject*) py_V9);
# 00659	        if (!PyArray_ISALIGNED((PyArrayObject*) py_V9)) {
# 00660	            PyArrayObject * tmp = (PyArrayObject*) py_V9;
# 00661	            PyErr_Format(PyExc_NotImplementedError,
# 00662	                         "expected an aligned array of type %ld "
# 00663	                         "(NPY_FLOAT64), got non-aligned array of type %ld"
# 00664	                         " with %ld dimensions, with 3 last dims "
# 00665	                         "%ld, %ld, %ld"
# 00666	                         " and 3 last strides %ld %ld, %ld.",
# 00667	                         (long int) NPY_FLOAT64,
# 00668	                         (long int) type_num_V9,
# 00669	                         (long int) PyArray_NDIM(tmp),
# 00670	                         (long int) PyArray_NDIM(tmp) >= 3 ?
# 00671	        PyArray_DIMS(tmp)[PyArray_NDIM(tmp)-3] : -1,
# 00672	                         (long int) PyArray_NDIM(tmp) >= 2 ?
# 00673	        PyArray_DIMS(tmp)[PyArray_NDIM(tmp)-2] : -1,
# 00674	                         (long int) PyArray_NDIM(tmp) >= 1 ?
# 00675	        PyArray_DIMS(tmp)[PyArray_NDIM(tmp)-1] : -1,
# 00676	                         (long int) PyArray_NDIM(tmp) >= 3 ?
# 00677	        PyArray_STRIDES(tmp)[PyArray_NDIM(tmp)-3] : -1,
# 00678	                         (long int) PyArray_NDIM(tmp) >= 2 ?
# 00679	        PyArray_STRIDES(tmp)[PyArray_NDIM(tmp)-2] : -1,
# 00680	                         (long int) PyArray_NDIM(tmp) >= 1 ?
# 00681	        PyArray_STRIDES(tmp)[PyArray_NDIM(tmp)-1] : -1
# 00682	        );
# 00683	            {
# 00684	        __failure = 10;
# 00685	        if (!PyErr_Occurred()) {
# 00686	            PyErr_SetString(PyExc_RuntimeError,
# 00687	                "Unexpected error in an Op's C code. "
# 00688	                "No Python exception was set.");
# 00689	            }
# 00690	        goto __label_10;}
# 00691	        }
# 00692	        // This is a TypeError to be consistent with DEBUG_MODE
# 00693	        // Note: DEBUG_MODE also tells the name of the container
# 00694	        if (type_num_V9 != NPY_FLOAT64) {
# 00695	            PyErr_Format(PyExc_TypeError,
# 00696	                         "expected type_num %d (NPY_FLOAT64) got %d",
# 00697	                         NPY_FLOAT64, type_num_V9);
# 00698	            {
# 00699	        __failure = 10;
# 00700	        if (!PyErr_Occurred()) {
# 00701	            PyErr_SetString(PyExc_RuntimeError,
# 00702	                "Unexpected error in an Op's C code. "
# 00703	                "No Python exception was set.");
# 00704	            }
# 00705	        goto __label_10;}
# 00706	        }
# 00707	        V9 = (PyArrayObject*)(py_V9);
# 00708	        Py_XINCREF(V9);
# 00709
# 00710	{
# 00711
# 00712
# 00713	    int elemsize ;
# 00714	    float fbeta;
# 00715	    double dbeta;
# 00716
# 00717	    if (PyArray_NDIM(V3) != 1)
# 00718	    {
# 00719	        PyErr_SetString(PyExc_NotImplementedError, "Gemv: rank(aa) != 1");
# 00720	        {
# 00721	        __failure = 11;
# 00722	        if (!PyErr_Occurred()) {
# 00723	            PyErr_SetString(PyExc_RuntimeError,
# 00724	                "Unexpected error in an Op's C code. "
# 00725	                "No Python exception was set.");
# 00726	            }
# 00727	        goto __label_11;};
# 00728	    }
# 00729	    if (PyArray_NDIM(V7) != 2)
# 00730	    {
# 00731	        PyErr_SetString(PyExc_NotImplementedError, "Gemv: rank(xx) != 2");
# 00732	        {
# 00733	        __failure = 11;
# 00734	        if (!PyErr_Occurred()) {
# 00735	            PyErr_SetString(PyExc_RuntimeError,
# 00736	                "Unexpected error in an Op's C code. "
# 00737	                "No Python exception was set.");
# 00738	            }
# 00739	        goto __label_11;};
# 00740	    }
# 00741	    if (PyArray_NDIM(V9) != 1)
# 00742	    {
# 00743	        PyErr_SetString(PyExc_NotImplementedError, "Gemv: rank(yy) != 1");
# 00744	        {
# 00745	        __failure = 11;
# 00746	        if (!PyErr_Occurred()) {
# 00747	            PyErr_SetString(PyExc_RuntimeError,
# 00748	                "Unexpected error in an Op's C code. "
# 00749	                "No Python exception was set.");
# 00750	            }
# 00751	        goto __label_11;};
# 00752	    }
# 00753	    if (PyArray_NDIM(V5) != 0)
# 00754	    {
# 00755	        PyErr_SetString(PyExc_NotImplementedError, "Gemv: rank(alpha) != 0");
# 00756	        {
# 00757	        __failure = 11;
# 00758	        if (!PyErr_Occurred()) {
# 00759	            PyErr_SetString(PyExc_RuntimeError,
# 00760	                "Unexpected error in an Op's C code. "
# 00761	                "No Python exception was set.");
# 00762	            }
# 00763	        goto __label_11;};
# 00764	    }
# 00765	    if (PyArray_NDIM(V5) != 0)
# 00766	    {
# 00767	        PyErr_SetString(PyExc_NotImplementedError, "Gemv: rank(beta) != 0");
# 00768	        {
# 00769	        __failure = 11;
# 00770	        if (!PyErr_Occurred()) {
# 00771	            PyErr_SetString(PyExc_RuntimeError,
# 00772	                "Unexpected error in an Op's C code. "
# 00773	                "No Python exception was set.");
# 00774	            }
# 00775	        goto __label_11;};
# 00776	    }
# 00777
# 00778	    if (PyArray_DESCR(V3)->type_num != PyArray_DESCR(V7)->type_num)
# 00779	    { PyErr_SetString(PyExc_TypeError, "Gemv: aa vs. xx"); {
# 00780	        __failure = 11;
# 00781	        if (!PyErr_Occurred()) {
# 00782	            PyErr_SetString(PyExc_RuntimeError,
# 00783	                "Unexpected error in an Op's C code. "
# 00784	                "No Python exception was set.");
# 00785	            }
# 00786	        goto __label_11;}; }
# 00787	    if (PyArray_DESCR(V3)->type_num != PyArray_DESCR(V9)->type_num)
# 00788	    { PyErr_SetString(PyExc_TypeError, "Gemv: aa vs. yy"); {
# 00789	        __failure = 11;
# 00790	        if (!PyErr_Occurred()) {
# 00791	            PyErr_SetString(PyExc_RuntimeError,
# 00792	                "Unexpected error in an Op's C code. "
# 00793	                "No Python exception was set.");
# 00794	            }
# 00795	        goto __label_11;}; }
# 00796
# 00797	    if (PyArray_DIMS(V7)[0] != PyArray_DIMS(V3)[0])
# 00798	    {
# 00799	        PyErr_SetString(PyExc_ValueError,
# 00800	                        "Shape mismatch: A.shape[0] != x.shape[0]");
# 00801	        {
# 00802	        __failure = 11;
# 00803	        if (!PyErr_Occurred()) {
# 00804	            PyErr_SetString(PyExc_RuntimeError,
# 00805	                "Unexpected error in an Op's C code. "
# 00806	                "No Python exception was set.");
# 00807	            }
# 00808	        goto __label_11;};
# 00809	    }
# 00810	    if (PyArray_DIMS(V7)[1] != PyArray_DIMS(V9)[0])
# 00811	    {
# 00812	        PyErr_SetString(PyExc_ValueError,
# 00813	                        "Shape mismatch: A.shape[1] != y.shape[0]");
# 00814	        {
# 00815	        __failure = 11;
# 00816	        if (!PyErr_Occurred()) {
# 00817	            PyErr_SetString(PyExc_RuntimeError,
# 00818	                "Unexpected error in an Op's C code. "
# 00819	                "No Python exception was set.");
# 00820	            }
# 00821	        goto __label_11;};
# 00822	    }
# 00823
# 00824	    if  (PyArray_DESCR(V3)->type_num == NPY_DOUBLE) { elemsize = 8; }
# 00825	    else if (PyArray_DESCR(V3)->type_num == NPY_FLOAT) { elemsize = 4;}
# 00826	    else {
# 00827	        PyErr_SetString(PyExc_NotImplementedError, "complex Gemv");
# 00828	        {
# 00829	        __failure = 11;
# 00830	        if (!PyErr_Occurred()) {
# 00831	            PyErr_SetString(PyExc_RuntimeError,
# 00832	                "Unexpected error in an Op's C code. "
# 00833	                "No Python exception was set.");
# 00834	            }
# 00835	        goto __label_11;};
# 00836	    }
# 00837
# 00838	    fbeta = dbeta = ((dtype_V5*)PyArray_DATA(V5))[0];
# 00839
# 00840	    // copy aa if not destructive
# 00841	    if (!0)
# 00842	    {
# 00843	        if ((NULL == V1)
# 00844	            || (PyArray_DIMS(V1)[0] != PyArray_DIMS(V3)[0]))
# 00845	        {
# 00846	            if (V1) Py_XDECREF(V1);
# 00847	            V1 = (PyArrayObject*)PyArray_SimpleNew(1,
# 00848	                PyArray_DIMS(V3), type_num_V3);
# 00849	            if(!V1) {
# 00850	                PyErr_SetString(PyExc_MemoryError,
# 00851	                                "failed to alloc gemv output");
# 00852	                {
# 00853	        __failure = 11;
# 00854	        if (!PyErr_Occurred()) {
# 00855	            PyErr_SetString(PyExc_RuntimeError,
# 00856	                "Unexpected error in an Op's C code. "
# 00857	                "No Python exception was set.");
# 00858	            }
# 00859	        goto __label_11;}
# 00860	            }
# 00861	        }
# 00862	        if (V1 == V3)
# 00863	        {
# 00864	            PyErr_SetString(PyExc_AssertionError, "V1 != V3");
# 00865	            {
# 00866	        __failure = 11;
# 00867	        if (!PyErr_Occurred()) {
# 00868	            PyErr_SetString(PyExc_RuntimeError,
# 00869	                "Unexpected error in an Op's C code. "
# 00870	                "No Python exception was set.");
# 00871	            }
# 00872	        goto __label_11;}
# 00873	        }
# 00874	        if (dbeta != 0)
# 00875	        {
# 00876	            if (PyArray_DESCR(V1)->type_num == NPY_FLOAT)
# 00877	            {
# 00878	                float * zoutdata = (float*)PyArray_DATA(V1);
# 00879	                const float * zdata = (float*)PyArray_DATA(V3);
# 00880	                int Ai = PyArray_STRIDES(V3)[0]/sizeof(float);
# 00881	                int Zi = PyArray_STRIDES(V1)[0]/sizeof(float);
# 00882	                for (int i = 0; i < PyArray_DIMS(V3)[0]; ++i)
# 00883	                {
# 00884	                    zoutdata[Zi*i] = fbeta * zdata[Ai*i];
# 00885	                }
# 00886	            }
# 00887	            else if (PyArray_DESCR(V7)->type_num == NPY_DOUBLE)
# 00888	            {
# 00889	                double * zoutdata = (double*) PyArray_DATA(V1);
# 00890	                const double * zdata = (double*)PyArray_DATA(V3);
# 00891	                int Ai = PyArray_STRIDES(V3)[0]/sizeof(double);
# 00892	                int Zi = PyArray_STRIDES(V1)[0]/sizeof(double);
# 00893	                for (int i = 0; i < PyArray_DIMS(V3)[0]; ++i)
# 00894	                {
# 00895	                    zoutdata[Zi*i] = dbeta * zdata[Ai*i];
# 00896	                }
# 00897	            }
# 00898	            else
# 00899	            {
# 00900	                PyErr_SetString(PyExc_AssertionError,
# 00901	                                "neither float nor double dtype");
# 00902	                {
# 00903	        __failure = 11;
# 00904	        if (!PyErr_Occurred()) {
# 00905	            PyErr_SetString(PyExc_RuntimeError,
# 00906	                "Unexpected error in an Op's C code. "
# 00907	                "No Python exception was set.");
# 00908	            }
# 00909	        goto __label_11;}
# 00910	            }
# 00911	            fbeta = dbeta = 1.0;
# 00912	        }
# 00913	    }
# 00914	    else
# 00915	    {
# 00916	        //fprintf(stderr, "Gemv working in-place \n");
# 00917	        if (V1 != V3)
# 00918	        {
# 00919	            if (V1) { Py_DECREF(V1); }
# 00920	            V1 = V3;
# 00921	            Py_INCREF(V1);
# 00922	        }
# 00923	    }
# 00924	    {
# 00925	        char TRANS = 'T';
# 00926	        char NOTRANS = 'N';
# ...
# 01058	                    else
# 01059	                    {
# 01060	                        dgemv_(&TRANS, &Nx1, &Nx0,
# 01061	                            &alpha,
# 01062	                            (double*)(PyArray_DATA(V7)), &Sx0,
# 01063	                            (double*)yy_data, &Sy,
# 01064	                            &dbeta,
# 01065	                            (double*)zz_data, &Sz);
# 01066	                    }
# 01067	                }
# 01068	                else
# 01069	                {
# 01070	                    PyErr_SetString(PyExc_AssertionError,
# 01071	                                    "neither float nor double dtype");
# 01072	                    {
# 01073	        __failure = 11;
# 01074	        if (!PyErr_Occurred()) {
# 01075	            PyErr_SetString(PyExc_RuntimeError,
# 01076	                "Unexpected error in an Op's C code. "
# 01077	                "No Python exception was set.");
# 01078	            }
# 01079	        goto __label_11;}
# 01080	                }
# 01081	            }
# 01082	            else
# 01083	            {
# 01084	                PyErr_SetString(PyExc_AssertionError,
# 01085	                    "xx is a double-strided matrix, and should have been "
# 01086	                    "copied into a memory-contiguous one.");
# 01087	                {
# 01088	        __failure = 11;
# 01089	        if (!PyErr_Occurred()) {
# 01090	            PyErr_SetString(PyExc_RuntimeError,
# 01091	                "Unexpected error in an Op's C code. "
# 01092	                "No Python exception was set.");
# 01093	            }
# 01094	        goto __label_11;}
# 01095	            }
# 01096	        }
# 01097	        else if (dbeta != 1.0)
# 01098	        {
# 01099	            // the matrix has at least one dim of length 0
# 01100	            // so we do this loop, which either iterates over 0 elements
# 01101	            // or else it does the right thing for length-0 x.
# 01102	            dtype_V1 * zptr = (dtype_V1*)(PyArray_DATA(V1));
# 01103	            for (int i = 0; i < Nx0; ++i)
# 01104	            {
# 01105	                zptr[i * Sz] *= dbeta;
# 01106	            }
# 01107	        }
# 01108	    }
# 01109
# 01110	    __label_11:
# 01111
# 01112	double __DUMMY_11;
# 01113
# 01114	}
# 01115	__label_10:
# 01116
# 01117	        if (V9) {
# 01118	            Py_XDECREF(V9);
# 01119	        }
# 01120
# 01121	    {Py_XDECREF(py_V9);}
# 01122
# 01123	double __DUMMY_10;
# 01124
# 01125	}
# 01126	__label_8:
# 01127
# 01128	        if (V7) {
# 01129	            Py_XDECREF(V7);
# 01130	        }
# 01131
# 01132	    {Py_XDECREF(py_V7);}
# 01133
# 01134	double __DUMMY_8;
# 01135
# 01136	}
# 01137	__label_6:
# 01138
# 01139	        if (V5) {
# 01140	            Py_XDECREF(V5);
# 01141	        }
# 01142
# 01143	    {Py_XDECREF(py_V5);}
# 01144
# 01145	double __DUMMY_6;
# 01146
# 01147	}
# 01148	__label_4:
# 01149
# 01150	        if (V3) {
# 01151	            Py_XDECREF(V3);
# 01152	        }
# 01153
# 01154	    {Py_XDECREF(py_V3);}
# 01155
# 01156	double __DUMMY_4;
# 01157
# 01158	}
# 01159	__label_2:
# 01160
# 01161	    if (!__failure) {
# 01162
# 01163	        {Py_XDECREF(py_V1);}
# 01164	        if (!V1) {
# 01165	            Py_INCREF(Py_None);
# 01166	            py_V1 = Py_None;
# 01167	        }
# 01168	        else if ((void*)py_V1 != (void*)V1) {
# 01169	            py_V1 = (PyObject*)V1;
# 01170	        }
# 01171
# 01172	        {Py_XINCREF(py_V1);}
# 01173
# 01174	        if (V1 && !PyArray_ISALIGNED((PyArrayObject*) py_V1)) {
# 01175	            PyErr_Format(PyExc_NotImplementedError,
# 01176	                         "c_sync: expected an aligned array of type %ld "
# 01177	                         "(NPY_FLOAT64), got non-aligned array of type %ld"
# 01178	                         " with %ld dimensions, with 3 last dims "
# 01179	                         "%ld, %ld, %ld"
# 01180	                         " and 3 last strides %ld %ld, %ld.",
# 01181	                         (long int) NPY_FLOAT64,
# 01182	                         (long int) type_num_V1,
# 01183	                         (long int) PyArray_NDIM(V1),
# 01184	                         (long int) PyArray_NDIM(V1) >= 3 ?
# 01185	        PyArray_DIMS(V1)[PyArray_NDIM(V1)-3] : -1,
# 01186	                         (long int) PyArray_NDIM(V1) >= 2 ?
# 01187	        PyArray_DIMS(V1)[PyArray_NDIM(V1)-2] : -1,
# 01188	                         (long int) PyArray_NDIM(V1) >= 1 ?
# 01189	        PyArray_DIMS(V1)[PyArray_NDIM(V1)-1] : -1,
# 01190	                         (long int) PyArray_NDIM(V1) >= 3 ?
# 01191	        PyArray_STRIDES(V1)[PyArray_NDIM(V1)-3] : -1,
# 01192	                         (long int) PyArray_NDIM(V1) >= 2 ?
# 01193	        PyArray_STRIDES(V1)[PyArray_NDIM(V1)-2] : -1,
# 01194	                         (long int) PyArray_NDIM(V1) >= 1 ?
# 01195	        PyArray_STRIDES(V1)[PyArray_NDIM(V1)-1] : -1
# 01196	        );
# 01197	            {
# 01198	        __failure = 2;
# 01199	        if (!PyErr_Occurred()) {
# 01200	            PyErr_SetString(PyExc_RuntimeError,
# 01201	                "Unexpected error in an Op's C code. "
# 01202	                "No Python exception was set.");
# 01203	            }
# 01204	        goto __label_2;}
# 01205	        }
# 01206
# 01207	      PyObject* old = PyList_GET_ITEM(storage_V1, 0);
# 01208	      {Py_XINCREF(py_V1);}
# 01209	      PyList_SET_ITEM(storage_V1, 0, py_V1);
# 01210	      {Py_XDECREF(old);}
# 01211	    }
# 01212
# 01213	        if (V1) {
# 01214	            Py_XDECREF(V1);
# 01215	        }
# 01216
# 01217	    {Py_XDECREF(py_V1);}
# 01218
# 01219	double __DUMMY_2;
# 01220
# 01221	}
# 01222
# 01223
# 01224	        if (__failure) {
# 01225	            // When there is a failure, this code puts the exception
# 01226	            // in __ERROR.
# 01227	            PyObject* err_type = NULL;
# 01228	            PyObject* err_msg = NULL;
# 01229	            PyObject* err_traceback = NULL;
# 01230	            PyErr_Fetch(&err_type, &err_msg, &err_traceback);
# 01231	            if (!err_type) {err_type = Py_None;Py_INCREF(Py_None);}
# 01232	            if (!err_msg) {err_msg = Py_None; Py_INCREF(Py_None);}
# 01233	            if (!err_traceback) {err_traceback = Py_None; Py_INCREF(Py_None);}
# 01234	            PyObject* old_err_type = PyList_GET_ITEM(__ERROR, 0);
# 01235	            PyObject* old_err_msg = PyList_GET_ITEM(__ERROR, 1);
# 01236	            PyObject* old_err_traceback = PyList_GET_ITEM(__ERROR, 2);
# 01237	            PyList_SET_ITEM(__ERROR, 0, err_type);
# 01238	            PyList_SET_ITEM(__ERROR, 1, err_msg);
# 01239	            PyList_SET_ITEM(__ERROR, 2, err_traceback);
# 01240	            {Py_XDECREF(old_err_type);}
# 01241	            {Py_XDECREF(old_err_msg);}
# 01242	            {Py_XDECREF(old_err_traceback);}
# 01243	        }
# 01244	        // The failure code is returned to index what code block failed.
# 01245	        return __failure;
# 01246
# 01247	        }
# 01248	    };
# 01249
# 01250
# 01251	        int __struct_compiled_op_c9411e9ce176ac05f48860cfa5375e97_executor(__struct_compiled_op_c9411e9ce176ac05f48860cfa5375e97* self) {
# 01252	            return self->run();
# 01253	        }
# 01254
# 01255	        void __struct_compiled_op_c9411e9ce176ac05f48860cfa5375e97_destructor(void* executor, void* self) {
# 01256	            delete ((__struct_compiled_op_c9411e9ce176ac05f48860cfa5375e97*)self);
# 01257	        }
# 01258
# 01259	//////////////////////
# 01260	////  Functions
# 01261	//////////////////////
# 01262	static PyObject * instantiate(PyObject * self, PyObject *argtuple) {
# 01263	  assert(PyTuple_Check(argtuple));
# 01264	  if (6 != PyTuple_Size(argtuple)){
# 01265	     PyErr_Format(PyExc_TypeError, "Wrong number of arguments, expected 6, got %i", (int)PyTuple_Size(argtuple));
# 01266	     return NULL;
# 01267	  }
# 01268	  __struct_compiled_op_c9411e9ce176ac05f48860cfa5375e97* struct_ptr = new __struct_compiled_op_c9411e9ce176ac05f48860cfa5375e97();
# 01269	  struct_ptr->init( PyTuple_GET_ITEM(argtuple, 0),PyTuple_GET_ITEM(argtuple, 1),PyTuple_GET_ITEM(argtuple, 2),PyTuple_GET_ITEM(argtuple, 3),PyTuple_GET_ITEM(argtuple, 4),PyTuple_GET_ITEM(argtuple, 5) );
# 01270	  PyObject* thunk = PyCObject_FromVoidPtrAndDesc((void*)(&__struct_compiled_op_c9411e9ce176ac05f48860cfa5375e97_executor), struct_ptr, __struct_compiled_op_c9411e9ce176ac05f48860cfa5375e97_destructor);
# 01271	  return thunk; }
# 01272
# 01273	//////////////////////
# 01274	////  Module init
# 01275	//////////////////////
# 01276	static PyMethodDef MyMethods[] = {
# 01277		{"instantiate", instantiate, METH_VARARGS, "undocumented"} ,
# 01278		{NULL, NULL, 0, NULL}
# 01279	};
# 01280	PyMODINIT_FUNC initc9411e9ce176ac05f48860cfa5375e97(void){
# 01281	   import_array();
# 01282	   (void) Py_InitModule("c9411e9ce176ac05f48860cfa5375e97", MyMethods);
# 01283	}
# 01284
# Problem occurred during compilation with the command line below:
# g++ -shared -g -O3 -fno-math-errno -Wno-unused-label -Wno-unused-variable -Wno-write-strings -Wl,-rpath,/home/kesj/lib -D NPY_NO_DEPRECATED_API=NPY_1_7_API_VERSION -m64 -fPIC -I/opt/edge/kesj/lib/shared_envs/common/lib/python2.7/site-packages/numpy/core/include -I/opt/edge/kesj/lib/shared_envs/common/include/python2.7 -o /home/kesj/.theano/compiledir_Linux-2.6.32-431.5.1.el6.x86_64-x86_64-with-redhat-6.5-Santiago-x86_64-2.7.9-64/tmp3d93gT/c9411e9ce176ac05f48860cfa5375e97.so /home/kesj/.theano/compiledir_Linux-2.6.32-431.5.1.el6.x86_64-x86_64-with-redhat-6.5-Santiago-x86_64-2.7.9-64/tmp3d93gT/mod.cpp -L/home/kesj/lib -L/opt/edge/kesj/lib/shared_envs/common/lib -lpython2.7 -lf77blas -lcblas -latlas
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-11-239d25676b11> in <module>()
# ----> 1 linear_mix = theano.function([A, x, theano.Param(b, default=np.array([0, 0]))], [y, z])
#       2 # We'll cover theano.config.floatX later
#       3 print linear_mix(np.array([[1, 2, 3],
#       4                            [4, 5, 6]], dtype=theano.config.floatX), #A
#       5                  np.array([1, 2, 3], dtype=theano.config.floatX), #x
#
# /opt/edge/kesj/lib/shared_envs/common/lib/python2.7/site-packages/theano/compile/function.pyc in function(inputs, outputs, mode, updates, givens, no_default_updates, accept_inplace, name, rebuild_strict, allow_input_downcast, profile, on_unused_input)
#     221                 allow_input_downcast=allow_input_downcast,
#     222                 on_unused_input=on_unused_input,
# --> 223                 profile=profile)
#     224     # We need to add the flag check_aliased inputs if we have any mutable or
#     225     # borrowed used defined inputs
#
# /opt/edge/kesj/lib/shared_envs/common/lib/python2.7/site-packages/theano/compile/pfunc.pyc in pfunc(params, outputs, mode, updates, givens, no_default_updates, accept_inplace, name, rebuild_strict, allow_input_downcast, profile, on_unused_input)
#     510     return orig_function(inputs, cloned_outputs, mode,
#     511             accept_inplace=accept_inplace, name=name, profile=profile,
# --> 512             on_unused_input=on_unused_input)
#     513
#     514
#
# /opt/edge/kesj/lib/shared_envs/common/lib/python2.7/site-packages/theano/compile/function_module.pyc in orig_function(inputs, outputs, mode, accept_inplace, name, profile, on_unused_input)
#    1310                    profile=profile,
#    1311                    on_unused_input=on_unused_input).create(
# -> 1312                        defaults)
#    1313
#    1314     t2 = time.time()
#
# /opt/edge/kesj/lib/shared_envs/common/lib/python2.7/site-packages/theano/compile/function_module.pyc in create(self, input_storage, trustme)
#    1179         # Get a function instance
#    1180         start_linker = time.time()
# -> 1181         _fn, _i, _o = self.linker.make_thunk(input_storage=input_storage_lists)
#    1182         end_linker = time.time()
#    1183
#
# /opt/edge/kesj/lib/shared_envs/common/lib/python2.7/site-packages/theano/gof/link.pyc in make_thunk(self, profiler, input_storage, output_storage)
#     432         return self.make_all(profiler=profiler,
#     433                              input_storage=input_storage,
# --> 434                              output_storage=output_storage)[:3]
#     435
#     436     def make_all(self, profiler, input_storage, output_storage):
#
# /opt/edge/kesj/lib/shared_envs/common/lib/python2.7/site-packages/theano/gof/vm.pyc in make_all(self, profiler, input_storage, output_storage)
#     845                                                  storage_map,
#     846                                                  compute_map,
# --> 847                                                  no_recycling))
#     848             except Exception, e:
#     849                 e.args = ("The following error happened while"
#
# /opt/edge/kesj/lib/shared_envs/common/lib/python2.7/site-packages/theano/gof/op.pyc in make_thunk(self, node, storage_map, compute_map, no_recycling)
#     604                 logger.debug('Trying CLinker.make_thunk')
#     605                 outputs = cl.make_thunk(input_storage=node_input_storage,
# --> 606                                         output_storage=node_output_storage)
#     607                 fill_storage, node_input_filters, node_output_filters = outputs
#     608
#
# /opt/edge/kesj/lib/shared_envs/common/lib/python2.7/site-packages/theano/gof/cc.pyc in make_thunk(self, input_storage, output_storage, keep_lock)
#     946         cthunk, in_storage, out_storage, error_storage = self.__compile__(
#     947             input_storage, output_storage,
# --> 948             keep_lock=keep_lock)
#     949
#     950         res = _CThunk(cthunk, init_tasks, tasks, error_storage)
#
# /opt/edge/kesj/lib/shared_envs/common/lib/python2.7/site-packages/theano/gof/cc.pyc in __compile__(self, input_storage, output_storage, keep_lock)
#     889                                     input_storage,
#     890                                     output_storage,
# --> 891                                     keep_lock=keep_lock)
#     892         return (thunk,
#     893                 [link.Container(input, storage) for input, storage in
#
# /opt/edge/kesj/lib/shared_envs/common/lib/python2.7/site-packages/theano/gof/cc.pyc in cthunk_factory(self, error_storage, in_storage, out_storage, keep_lock)
#    1320         else:
#    1321             module = get_module_cache().module_from_key(
# -> 1322                 key=key, fn=self.compile_cmodule_by_step, keep_lock=keep_lock)
#    1323
#    1324         vars = self.inputs + self.outputs + self.orphans
#
# /opt/edge/kesj/lib/shared_envs/common/lib/python2.7/site-packages/theano/gof/cmodule.pyc in module_from_key(self, key, fn, keep_lock, key_data)
#     994                                 # The module should be returned by the last
#     995                                 # step of the compilation.
# --> 996                                 module = next(compile_steps)
#     997                             except StopIteration:
#     998                                 break
#
# /opt/edge/kesj/lib/shared_envs/common/lib/python2.7/site-packages/theano/gof/cc.pyc in compile_cmodule_by_step(self, location)
#    1235                     lib_dirs=self.lib_dirs(),
#    1236                     libs=libs,
# -> 1237                     preargs=preargs)
#    1238             except Exception, e:
#    1239                 e.args += (str(self.fgraph),)
#
# /opt/edge/kesj/lib/shared_envs/common/lib/python2.7/site-packages/theano/gof/cmodule.pyc in compile_str(module_name, src_code, location, include_dirs, lib_dirs, libs, preargs, py_module)
#    1969             # difficult to read.
#    1970             raise Exception('Compilation failed (return status=%s): %s' %
# -> 1971                             (status, compile_stderr.replace('\n', '. ')))
#    1972         elif config.cmodule.compilation_warning and compile_stderr:
#    1973             # Print errors just below the command line.
#
# Exception: ('The following error happened while compiling the node', CGemv{no_inplace}(b, TensorConstant{1.0}, A, x, TensorConstant{1.0}), '\n', 'Compilation failed (return status=1): /usr/bin/ld: cannot find -latlas. collect2: ld returned 1 exit status. ', '[CGemv{no_inplace}(b, TensorConstant{1.0}, A, x, TensorConstant{1.0})]')

# %%
A = T.matrix('A')
x = T.vector('x')
b = T.vector('b')
y = T.dot(A, x) + b
# Note that squaring a matrix is element-wise
z = T.sum(A**2)
# theano.function can compute multiple things at a time
# You can also set default parameter values
linear_mix = theano.function([A, x, theano.Param(b, default=np.array([0, 0]))], [y, z])
# We'll cover theano.config.floatX later
print linear_mix(np.array([[1, 2, 3],
                           [4, 5, 6]], dtype=theano.config.floatX), #A
                 np.array([1, 2, 3], dtype=theano.config.floatX), #x
                 np.array([4, 5], dtype=theano.config.floatX)) #b
# Using the default value for b
print linear_mix(np.array([[1, 2, 3],
                           [4, 5, 6]]), #A
                 np.array([1, 2, 3])) #x

# %%
theano.Param()
